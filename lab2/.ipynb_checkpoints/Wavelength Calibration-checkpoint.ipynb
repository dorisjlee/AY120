# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
cd ../lab2/ROBOT_lab2/
# Out:
# /Users/dorislee/Desktop/Fall2014/AY120/lab2/ROBOT_lab2

# %%
#Check the units of Intensity???
def plot_spectra(filename,title="Spectroscopic Spectra"):
    data = np.genfromtxt(filename, skip_header=17, skip_footer=1)
    plt.figure()
    plt.title(title)
    plt.xlabel("Pixel Number",fontsize=12)
    plt.ylabel("Intensity",fontsize=12)
    plt.xlim(0,2048)
    plt.plot(data[:,1])

# %%
import glob
def average(glob_text,title="Spectroscopic Spectra",plot = False):
    data_lst = glob.glob(glob_text)
    num_sets=len(data_lst)
    #Lets just print the first 10 for now...
    x = np.zeros((2048,),'float64')
    I = np.zeros((2048,),'float64')
    for i in data_lst:
        data = np.genfromtxt(i, skip_header=17, skip_footer=1)
#         x = x + data[:,0]
        x = data[:,0]
        I = I + data[:,1]
    if plot:
        plt.figure()
        plt.title("100 sample of 1s dark counts")
        plt.xlim(0,2048)
        plt.xlabel("Pixel Number",fontsize=12)
        plt.ylabel("Intensity[ADU]",fontsize=12)
        plt.plot(x,I/num_sets)
    print "Number of samples: ",num_sets
    return np.array([x,I/num_sets])

# %%
average("plasma_bulb*.txt",plot=True)
# Out:
# Number of samples:  100
# array([[  0.00000000e+00,   1.00000000e+00,   2.00000000e+00, ...,
#           2.04500000e+03,   2.04600000e+03,   2.04700000e+03],
#        [  0.00000000e+00,   1.20760000e+02,   1.21820000e+02, ...,
#           1.47120000e+02,   1.44180000e+02,   1.37280000e+02]])

# %% [markdown]
# # Finding Centroid on Mercury Spectral Lines

# %% [markdown]
# Looks like there are less of these, easier to use eyeball method

# %%
def centroid(data):
    '''
    simple centroid calculation, assuming that the data is preprocessed
    '''
    centroid_lst=[]
    numerator = float(np.sum(data[:,1]*data[:,0]))
    cval=numerator/np.sum(data[:,1])
    return cval

# %%
# def centroid_between(left,right,data,plot=False):
#     data = data[left:right]
#     print (sliced_data)
#     centroid_lst=[]
#     numerator = float(np.sum(data[:,1]*data[:,0]))
#     cval=numerator/np.sum(data[:,1])
#     if (plot):
#         ax = plt.gca()
#         plt.plot([cval,cval],[ax.get_ylim()[0],ax.get_ylim()[1]],'r',linestyle='dashdot');
#     return cval

# %%
def eyeball(start,end):
#     data  = average("roomlight_*",plot=True)
    filename="roomlight_50ms_0000.txt"
    data = np.genfromtxt(filename, skip_header=17, skip_footer=1)
    plt.plot(data[start:end,0],data[start:end,1])
    ax = plt.gca()
    cval = centroid(data[start:end])
    plt.plot([cval,cval],[ax.get_ylim()[0],ax.get_ylim()[1]],'r',linestyle='dashdot');
    print cval
    return cval

# %%
eyeball(0,2048)
# Out:
# 1099.05951961
# 1099.0595196099762

# %%
cval_lst=[]

# %%
# cval = eyeball(101,110)
# cval_lst.append(cval)

# %%
cval = eyeball(310,320)
cval_lst.append(cval)
# Out:
# 314.392857143

# %%
cval_lst.append(eyeball(477,490))
# Out:
# 483.013292434

# %%
cval=eyeball(1050,1200)
cval_lst.append(cval)
# Out:
# 1115.54862329

# %%
cval=eyeball(1365,1385)
cval_lst.append(cval)
# Out:
# 1374.82635906

# %%
cval=eyeball(1520,1538)
cval_lst.append(cval)
# Out:
# 1529.81868113

# %%
eyeball(1650,1675)
# Out:
# 1661.67704746
# 1661.6770474621949

# %%
cval_lst
# Out:
# [314.39285714285717,
#  483.01329243353786,
#  1115.5486232866895,
#  1374.8263590624617,
#  1529.818681126465]

# %%
filename="roomlight_50ms_0000.txt"
data = np.genfromtxt(filename, skip_header=17, skip_footer=1)
plt.plot(data[:,0],data[:,1])
ax = plt.gca()
plt.xlim(0,2048)
for cval in cval_lst:
    plt.plot([cval,cval],[ax.get_ylim()[0],ax.get_ylim()[1]],'r',linestyle='dashdot');
for cval in cval_lst[:-2]:
    ax.annotate(str(int(cval)),xy=(cval,10), xytext=(cval-75,-150),fontsize=12)
cval =1374
ax.annotate(str(int(cval)),xy=(cval,10), xytext=(cval-100,-150),fontsize=12)
cval =1530
ax.annotate(str(int(cval)),xy=(cval,10), xytext=(cval-20,-150),fontsize=12)
plt.ylabel("Intensity[ADU]",fontsize=12)
plt.xlabel("Pixel",fontsize=12,labelpad=10)
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
ax.axes.xaxis.set_ticklabels([])
plt.title("Spectral lines of fluroescent roomlight (50ms)",fontsize=12)

# %% [markdown]
# # Finding Centroid on Neon Spectral Lines

# %%
def eyeball_neon(start,end):
    filename="neon_700ms_0001.txt"
    data = np.genfromtxt(filename, skip_header=17, skip_footer=1)
    plt.plot(data[start:end,0],data[start:end,1])
    ax = plt.gca()
    cval = centroid(data[start:end])
    plt.plot([cval,cval],[ax.get_ylim()[0],ax.get_ylim()[1]],'r',linestyle='dashdot');
    print cval
    return cval

# %%
cval_lst_neon=[]

# %%
cval_lst_neon.append(eyeball_neon(1355,1370))
# Out:
# 1362.13777939

# %%
cval_lst_neon.append(eyeball_neon(1415,1425))
# Out:
# 1419.89571695

# %%
cval_lst_neon.append(eyeball_neon(1545,1555))
# Out:
# 1549.60886603

# %%
cval_lst_neon.append(eyeball_neon(1558,1568))
# Out:
# 1562.26709879

# %%
cval_lst_neon.append(eyeball_neon(1594,1605))
# Out:
# 1599.10751538

# %%
cval_lst_neon.append(eyeball_neon(1627,1636))
# Out:
# 1631.4750049

# %%
cval_lst_neon.append(eyeball_neon(1675,1680))
# Out:
# 1677.12301013

# %%
cval_lst_neon.append(eyeball_neon(1706.5,1714))
# Out:
# 1710.24108332

# %%
cval_lst_neon.append(eyeball_neon(1720,1730))
# Out:
# 1724.19037222

# %%
cval_lst_neon.append(eyeball_neon(1793,1800))
# Out:
# 1796.05346966

# %%
cval_lst_neon.append(eyeball_neon(1858,1865))
# Out:
# 1861.10272703

# %%
cval_lst_neon.append(eyeball_neon(1915,1921))
# Out:
# 1917.58923317

# %%
cval_lst_neon
# Out:
# [1362.1377793915919,
#  1419.8957169459964,
#  1549.6088660298799,
#  1562.2670987930264,
#  1599.1075153784434,
#  1631.4750049009997,
#  1677.123010130246,
#  1710.2410833210004,
#  1724.1903722187565,
#  1796.0534696614147,
#  1861.102727032036,
#  1917.5892331660032]

# %%
filename="roomlight_50ms_0000.txt"
fig = plt.figure()
ax = fig.add_subplot(211)
data = np.genfromtxt(filename, skip_header=17, skip_footer=1)
plt.plot(data[:,0],data[:,1])

# ax = plt.gca()
plt.xlim(0,2048)
for cval in cval_lst:
    plt.plot([cval,cval],[ax.get_ylim()[0],ax.get_ylim()[1]],'r',linestyle='dashdot');
for cval in cval_lst[:-2]:
    ax.annotate(str(int(cval)),xy=(cval,10), xytext=(cval-75,-420),fontsize=12)
cval =1374
ax.annotate(str(int(cval)),xy=(cval,10), xytext=(cval-100,-420),fontsize=12)
cval =1530
ax.annotate(str(int(cval)),xy=(cval,10), xytext=(cval-20,-420),fontsize=12)
plt.ylabel("Intensity[ADU]",fontsize=12)
# plt.xlabel("Pixel",fontsize=12,labelpad=10)
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
ax.axes.xaxis.set_ticklabels([])
plt.title("Spectral lines of fluroescent roomlight (50ms)",fontsize=12)

filename="neon_700ms_0000.txt"
ax2 = fig.add_subplot(212)
data = np.genfromtxt(filename, skip_header=17, skip_footer=1)
plt.plot(data[1350:,0],data[1350:,1])
# ax = plt.gca()
plt.xlim(1350,2000)
for cval in cval_lst_neon:
    plt.plot([cval,cval],[ax2.get_ylim()[0],ax2.get_ylim()[1]],'r',linestyle='dashdot');
for cval in [cval_lst_neon[0],cval_lst_neon[1],cval_lst_neon[2],cval_lst_neon[4],cval_lst_neon[5],cval_lst_neon[6],cval_lst_neon[7],cval_lst_neon[9],cval_lst_neon[10],cval_lst_neon[11]]:
    ax2.annotate(str(int(cval)),xy=(cval,10), xytext=(cval-15,-420),fontsize=7)
# cval =1374
# ax.annotate(str(int(cval)),xy=(cval,10), xytext=(cval-100,-150),fontsize=12)
# cval =1530
# ax.annotate(str(int(cval)),xy=(cval,10), xytext=(cval-20,-150),fontsize=12)
plt.ylabel("Intensity[ADU]",fontsize=12)
plt.xlabel("Pixel",fontsize=12,labelpad=10)
for tick in ax2.yaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
ax2.axes.xaxis.set_ticklabels([])
plt.title("Spectral lines of neon (700ms)",fontsize=12)
plt.tight_layout()

# %% [markdown]
# # Centroid algorithm (Failed...)

# %%
filename="roomlight_50ms_0000.txt"
data = np.genfromtxt(filename, skip_header=17, skip_footer=1)

# %%
import numpy as np
from scipy.signal import argrelextrema
# for local maxima
lmax = argrelextrema(data[:,1], np.greater)[0]
# for local minima
fig = plt.figure()
ax=fig.add_subplot(211)
lmin = argrelextrema(data[:,1], np.less)[0]
plt.xlim(1000,1200)
# plt.xlim(1800,1900)
plt.plot(data[:,1])
for i in lmax:
    plt.plot(i,data[i,1],'o',color="red")
for i in lmin:
    plt.plot(i,data[i,1],'o',color="green")
plt.ylabel("Intensity[ADU]",fontsize=12)
plt.xlabel("Pixel",fontsize=12,labelpad=10)
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
# ax.axes.xaxis.set_ticklabels([])
plt.title("Spectral lines identification failure",fontsize=12)
ax2=fig.add_subplot(212)
lmin = argrelextrema(data[:,1], np.less)[0]
plt.xlim(1290,1450)
plt.ylim(0,550)
# plt.xlim(1800,1900)
plt.plot(data[:,1])
for i in lmax:
    plt.plot(i,data[i,1],'o',color="red")
for i in lmin:
    plt.plot(i,data[i,1],'o',color="green")
plt.ylabel("Intensity[ADU]",fontsize=12)
plt.xlabel("Pixel",fontsize=12,labelpad=10)
for tick in ax2.yaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
for tick in ax2.xaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
# ax2.axes.xaxis.set_ticklabels([])

# %%
import numpy as np
from scipy.signal import argrelextrema
# for local maxima
lmax = argrelextrema(data[:,1], np.greater)[0]
# for local minima
lmin = argrelextrema(data[:,1], np.less)[0]
# plt.xlim(1300,2048)
# plt.xlim(1800,1900)
fig = plt.figure()
plt.title("Automated centroid-finding algorithm steps")
ax = fig.add_subplot(311)
plt.plot(data[:,1])
for i in lmax:
    plt.plot(i,data[i,1],'.',color="red")
for i in lmin:
    plt.plot(i,data[i,1],'.',color='green')
plt.xlim(0,2048)
ax.axes.xaxis.set_ticklabels([])
ax.axes.yaxis.set_ticklabels([])
ax2 = fig.add_subplot(312)
plt.xlim(1500,1580)
plt.plot(data[:,1])
for i in lmax:
    plt.plot(i,data[i,1],'o',color="red")
for i in lmin:
    plt.plot(i,data[i,1],'o',color='green')
cval=1529
plt.plot([cval,cval],[ax.get_ylim()[0],ax.get_ylim()[1]],'r',linestyle='dashdot');
ax2.axes.xaxis.set_ticklabels([])
ax2.axes.yaxis.set_ticklabels([])
ax3 = fig.add_subplot(313)
filename="roomlight_50ms_0000.txt"
data = np.genfromtxt(filename, skip_header=17, skip_footer=1)
plt.plot(data[:,0],data[:,1])
# ax = plt.gca()
plt.xlim(0,2048)
cval_lst=[483,1536]
for cval in cval_lst:
    plt.plot([cval,cval],[ax.get_ylim()[0],ax.get_ylim()[1]],'r',linestyle='dashdot');
for cval in cval_lst[:-2]:
    ax3.annotate(str(int(cval)),xy=(cval,10), xytext=(cval-75,-500),fontsize=12)
cval =1530
ax3.annotate(str(int(cval)),xy=(cval,10), xytext=(cval-20,-500),fontsize=12)
plt.ylabel("Intensity[ADU]",fontsize=12,labelpad=30)
plt.xlabel("Pixel",fontsize=12,labelpad=30)
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
ax3.axes.xaxis.set_ticklabels([])
ax3.axes.yaxis.set_ticklabels([])
# Out:
# []

# %% [markdown]
# # Wavelength calibration

# %% [markdown]
# Determine the wavelength calibration of the spectrometer, i.e., the mapping between
# pixel number and wavelength. Do this by measuring the centroids (i.e., pixel positions) of bright Hg I (fluorescent room lights) and Ne I lines of known wavelength. Then use the method of linear least squares to determine a polynomial fit to these data.

# %%
pix_neon = np.array(cval_lst_neon)
print pix_neon
cval_lst = np.array([314.39285714285717, 483.01329243353786, 1115.5486232866895, 1374.8263590624617, 1529.818681126465]) # pixel position from center (from centroid calculation)
pix_hg = np.array(cval_lst)
print pix_hg
pix = np.concatenate([pix_neon,pix_hg])
print pix
wavelength_hg = np.array([404.6563,435.8328,546.0735,576.9598,579.0663]) #given from NIST
wavelength_neon = np.array([585.24879,594.48342,614.30626,616.35939,621.72812,626.6495,633.44278,638.29917,640.2248,650.65281,659.89529,667.82762]) #given from NIST
wavelength = np.concatenate([wavelength_neon,wavelength_hg])
print wavelength
# print len(pix)
# print len(wavelength)
assert len(pix) == len(wavelength)
z = np.polyfit(pix, wavelength, 3) #lets fit to 5th order, but we'll probably find that the  3,4th order coefficient is 0  (becareful not to overfit) 
print z
p = np.poly1d(z)
print p

fig = plt.figure()
ax = fig.add_subplot(311)
plt.plot(np.arange(0,2032),p(np.arange(0,2032)))
plt.xlim(0,2032)
plt.title("Wavelength",fontsize=12)
plt.ylabel("$\lambda$[nm]",fontsize=12)
plt.xlabel("Pixel",fontsize=12)
ax.text(0.01, 0.8,"$\lambda_i = {}x^3+{}x^2+{}x+{}$".format(z[0],z[1],z[2],z[3]), fontsize=12,transform=ax.transAxes)
# Out:
# [ 1362.13777939  1419.89571695  1549.60886603  1562.26709879  1599.10751538
#   1631.4750049   1677.12301013  1710.24108332  1724.19037222  1796.05346966
#   1861.10272703  1917.58923317]
# [  314.39285714   483.01329243  1115.54862329  1374.82635906  1529.81868113]
# [ 1362.13777939  1419.89571695  1549.60886603  1562.26709879  1599.10751538
#   1631.4750049   1677.12301013  1710.24108332  1724.19037222  1796.05346966
#   1861.10272703  1917.58923317   314.39285714   483.01329243  1115.54862329
#   1374.82635906  1529.81868113]
# [ 585.24879  594.48342  614.30626  616.35939  621.72812  626.6495
#   633.44278  638.29917  640.2248   650.65281  659.89529  667.82762
#   404.6563   435.8328   546.0735   576.9598   579.0663 ]
# [  1.70885699e-08  -6.58721144e-05   2.38333264e-01   3.35224615e+02]
#            3             2
# 1.709e-08 x - 6.587e-05 x + 0.2383 x + 335.2

# %% [markdown]
# ### Linear Residual

# %%
z = np.polyfit(pix, wavelength, 1) #lets fit to 5th order, but we'll probably find that the  3,4th order coefficient is 0  (becareful not to overfit) 
print z
p = np.poly1d(z)
print p
residual=(wavelength-p(pix))#**2
plt.title("Linear residual",fontsize =12)
plt.xlabel("Pixel",fontsize =12)
plt.ylabel("$\lambda_ {error}$[nm]",fontsize =12)
plt.plot(pix,residual,'o')
plt.ylim(-10,10)
# Out:
# [  1.63801155e-01   3.56326332e+02]
#
# 0.1638 x + 356.3
# (-10, 10)

# %%
sum(residual)
# Out:
# -2.1600499167107046e-12

# %% [markdown]
# ### Quadratic Residual

# %%
z = np.polyfit(pix, wavelength, 2) #lets fit to 5th order, but we'll probably find that the  3,4th order coefficient is 0  (becareful not to overfit) 
print z
p = np.poly1d(z)
print p
residual=(wavelength-p(pix))#**2
plt.title("Quadratic residual",fontsize =12)
plt.xlabel("Pixel",fontsize =12)
plt.ylabel("$\lambda_{error}$[nm]",fontsize =12)
plt.plot(pix,residual,'o')
plt.ylim(0,5)
# Out:
# [ -5.10054454e-06   1.75132582e-01   3.51556386e+02]
#             2
# -5.101e-06 x + 0.1751 x + 351.6
# (0, 5)

# %%
sum(residual)
# Out:
# -9.2654772743117064e-12

# %% [markdown]
# ### Testing manufactuere with our data to see residual

# %%
# z = np.polyfit(pix, wavelength, 2) #lets fit to 5th order, but we'll probably find that the  3,4th order coefficient is 0  (becareful not to overfit) 
# print z
p = np.poly1d([-1.4913e-5,0.19743726,344.311846])
print p
residual=(wavelength-p(pix))#**2
plt.title("Manufactuerer's residual",fontsize =12)
plt.xlabel("Pixel",fontsize =12)
plt.ylabel("$\lambda_{error}$[nm]",fontsize =12)
plt.plot(pix,residual,'o')
# plt.ylim(0,5)
# Out:
#             2
# -1.491e-05 x + 0.1974 x + 344.3

# %%
sum([i for i in residual if abs(i)<5 ])
# Out:
# -2.2916943803557501

# %%
z = np.polyfit(pix, wavelength, 1) #lets fit to 5th order, but we'll probably find that the  3,4th order coefficient is 0  (becareful not to overfit) 
print z
p = np.poly1d(z)
print p
residual=(wavelength-p(pix))#**2
fig = plt.figure()
fig.add_subplot(211)
plt.xlabel("Pixel",fontsize =12)
plt.ylabel("$\lambda_ {error}$[nm]",fontsize =12)
plt.plot(pix,residual,'o',label="Linear residual")
plt.ylim(-10,10)
z = np.polyfit(pix, wavelength, 2) #lets fit to 5th order, but we'll probably find that the  3,4th order coefficient is 0  (becareful not to overfit) 
print z
p = np.poly1d(z)
print p
residual=(wavelength-p(pix))#**2
plt.title("Residuals from linear and quadratic fit",fontsize =12)
plt.xlabel("Pixel",fontsize =12)
plt.ylabel("$\lambda_{error}$[nm]",fontsize =12)
plt.plot(pix,residual,'o',color="red",label="Quadratic residual")
plt.ylim(0,5)
from matplotlib.legend_handler import HandlerLine2D
plt.legend(loc='upper left',prop={'size':12},numpoints=1)
# Out:
# [  1.63801155e-01   3.56326332e+02]
#
# 0.1638 x + 356.3
# [ -5.10054454e-06   1.75132582e-01   3.51556386e+02]
#             2
# -5.101e-06 x + 0.1751 x + 351.6

# %%
sum(residual)
# Out:
# -9.2654772743117064e-12

# %%
fig = plt.figure()
ax1 = fig.add_subplot(312)
z = np.polyfit(pix, wavelength, 1) #lets fit to 5th order, but we'll probably find that the  3,4th order coefficient is 0  (becareful not to overfit) 
print z
p = np.poly1d(z)
print p
residual=(wavelength-p(pix))#**2
plt.title("Linear residual",fontsize =12)
# plt.xlabel("Pixel",fontsize =12)
plt.ylabel("$\lambda_ {error}$[nm]",fontsize =12)
# a = plt.gca()

plt.plot(pix,residual,'o')
plt.ylim(-10,10)
ax2 = fig.add_subplot(313)
z = np.polyfit(pix, wavelength, 2) #lets fit to 5th order, but we'll probably find that the  3,4th order coefficient is 0  (becareful not to overfit) 
print z
p = np.poly1d(z)
print p
residual=(wavelength-p(pix))#**2
plt.title("Quadratic residual",fontsize =12)
plt.xlabel("Pixel",fontsize =12)
plt.ylabel("$\lambda_{error}$[nm]",fontsize =12)
plt.plot(pix,residual,'o')
plt.ylim(0,5)
ax0 = fig.add_subplot(311)
ax0.set_yticks(np.arange(300,701,100))
z = np.polyfit(pix, wavelength, 3) #lets fit to 5th order, but we'll probably find that the  3,4th order coefficient is 0  (becareful not to overfit) 
print z
p = np.poly1d(z)
print p
plt.plot(np.arange(0,2032),p(np.arange(0,2032)),color="red",label = "Polynomial Fit Result")
plt.plot(pix,wavelength,'o',label="Experimental Result")
# from matplotlib.legend_handler import HandlerLine2D
# plt.legend(loc='upper left',prop={'size':12})
plt.xlim(0,2032)
plt.title("Wavelength calibration from Ne and Hg spectra",fontsize=12)
plt.ylabel("$\lambda$[nm]",fontsize=12)
# plt.xlabel("Pixel",fontsize=12)
ax.text(0.01, 0.8,"$\lambda_i = {}x^3+{}x^2+{}x+{}$".format(z[0],z[1],z[2],z[3]), fontsize=12,transform=ax.transAxes)
plt.tight_layout()
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(12)
# Out:
# [  1.63801155e-01   3.56326332e+02]
#
# 0.1638 x + 356.3
# [ -5.10054454e-06   1.75132582e-01   3.51556386e+02]
#             2
# -5.101e-06 x + 0.1751 x + 351.6
# [  1.70885699e-08  -6.58721144e-05   2.38333264e-01   3.35224615e+02]
#            3             2
# 1.709e-08 x - 6.587e-05 x + 0.2383 x + 335.2

# %% [markdown]
# # Dark Subtraction

# %%
def subtract(datafile,darkfile,plot=True):
    data = np.genfromtxt(datafile, skip_header=17, skip_footer=1)
    darkdata = np.genfromtxt(darkfile, skip_header=17, skip_footer=1)
    if (plot):
        fig = plt.figure()
        ax = fig.add_subplot(311)
        plt.xlabel("Pixel Number",fontsize=12)
        plt.ylabel("Intensity[ADU]",fontsize=12)
        plt.title("Neon Spectra and Bias frames",fontsize=12)
        plt.plot(darkdata[:,1],color="red",label="Dark Counts")
        plt.plot(data[:,1],label ="Signal")
        plt.xlim(0,2032)
        plt.ylim(0,500)
        from matplotlib.legend_handler import HandlerLine2D
        plt.legend(loc='upper left',prop={'size':10})
        for tick in ax.xaxis.get_major_ticks():
            tick.label.set_fontsize(12) 
        for tick in ax.yaxis.get_major_ticks():
            tick.label.set_fontsize(12) 
    print len(data)==len(darkdata)
    subtracted = data-darkdata
    if plot :
        fig2 = plt.figure()
        fig2.add_subplot(211)
        plt.plot(data[:,1])
        plt.xlim(1000,2032)
        fig2.add_subplot(212)
        plt.plot(subtracted[:,1])
        plt.xlim(1000,2032)
    return subtracted

# %%
subtract("neon_700ms_0000.txt","dark_1s_0000.txt")
# Out:
# True
# array([[ 0.,  0.],
#        [ 0., -2.],
#        [ 0., -1.],
#        ...,
#        [ 0., -1.],
#        [ 0.,  1.],
#        [ 0., -1.]])

# %% [markdown]
# ### Read noise and Gain

# %%
pix = []
pix.append(0.)
pix.append(0.)
pix.append(0.)
print pix
# Out:
# [0.0, 0.0, 0.0]

# %%
filename="plasma_bulb0000.txt"
data = np.genfromtxt(filename, skip_header=17, skip_footer=1)
plt.plot(data[:,1])

# %%
glob_text="plasma_bulb*.txt"
data_lst = glob.glob(glob_text)
num_sets=len(data_lst)
# x = np.zeros((2048,),'float64')
I = np.zeros((2048,),'float64')
#     print num_sets
mega_Idata = []
for i in data_lst:
    data = np.genfromtxt(i, skip_header=17, skip_footer=1)
    mega_Idata.append(data[:,1])
# print mega_Idata
pix1 = []
for i in mega_Idata:
#     print i 
#     print i[0]
    pix1.append(i[1300])
#     print pix1
plt.figure()
plt.title(glob_text)
plt.plot(pix1[:120])

# %% [markdown]
# Investigate the variability in data to pick out the best source to use (best now we are forced to use plasma bulb because of integration time of dark counts)

# %%
# glob_text_lst = ["neon_700ms_*.txt","sunlight_*.txt", "SSunlight*","roomlight_50ms_*","plasma_bulb*","60w_lightbulb_10ms*","Halogen_5ms_*"]
# for glob_text in glob_text_lst:
#     data_lst = glob.glob(glob_text)
#     num_sets=len(data_lst)
#     # x = np.zeros((2048,),'float64')
#     I = np.zeros((2048,),'float64')
# #     print num_sets
#     mega_Idata = []
#     for i in data_lst:
#         data = np.genfromtxt(i, skip_header=17, skip_footer=1)
#         mega_Idata.append(data[:,1])
#     # print mega_Idata
#     pix1 = []
#     for i in mega_Idata:
#     #     print i 
#     #     print i[0]
#         pix1.append(i[1000])
# #     print pix1
#     plt.figure()
#     plt.title(glob_text)
#     plt.plot(pix1)

# %%
data_lst = glob.glob("plasma_bulb*")
num_sets=len(data_lst)
# x = np.zeros((2048,),'float64')
I = np.zeros((2048,),'float64')
#     print num_sets
mega_Idata = []
for i in data_lst:
    data = np.genfromtxt(i, skip_header=17, skip_footer=1)
    mega_Idata.append(data[:,1])
# print mega_Idata
mega_pixdata = []
for n in np.arange(2048):
    pix1 = []
    for i in mega_Idata:
    #     print i 
    #     print i[0]
        pix1.append(i[n])
    mega_pixdata.append(pix1)
fig = plt.figure()
ax = fig.add_subplot(211)
# plt.title(glob_text)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
plt.plot(pix1)
# ax2 = fig.add_subplot(212)
# plt.plot(pix1[:125])
# plt.xlabel("Sample",fontsize=12)
# plt.ylabel("Signal[ADU]",fontsize=12)
# for tick in ax2.xaxis.get_major_ticks():
#     tick.label.set_fontsize(12) 
# for tick in ax2.yaxis.get_major_ticks():
#     tick.label.set_fontsize(12) 
plt.tight_layout()

# %%
# print mega_pixdata[:10]
print len(mega_pixdata)
# Out:
# 2048

# %%
mulst = []
varlst=[]
for i in mega_Idata:
    mu = np.mean(i)
    var = np.std(i)**2
    mulst.append(mu)
    varlst.append(var)
plt.ylabel("Variance[ADU^2]")
plt.xlabel("Mean[ADU]")
plt.xlim(10**2,3*10**2)
plt.loglog(mulst,varlst,'.')

# %% [markdown]
# Dark Subtract

# %%
# average("roomlight_50ms_*",plot=False).shape

# %%
cd ../Robot/
# Out:
# /Users/dorislee/Desktop/Fall2014/AY120/lab2/Robot

# %%
filename = "darkness_3ms_0000.txt"

fig = plt.figure()
ax = fig.add_subplot(311)
data = np.genfromtxt(filename, skip_header=17, skip_footer=1)
plt.plot(data[:,1])
title = "A spectrum of 3ms dark counts"
plt.title(title,fontsize=12)
plt.xlim(0,2048)
plt.ylim(100,120)
plt.xlabel("Pixel Number",fontsize=12)
plt.ylabel("Intensity[ADU]",fontsize=12)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(12)

# %%
dark = average("darkness_3ms*.txt",plot=True)
plt.plot(np.arange(2048),dark[:,1])
# Out:
# Number of samples:  1000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-17da7dd43cc4> in <module>()
#       1 dark = average("darkness_3ms*.txt",plot=True)
# ----> 2 plt.plot(np.arange(2048),dark[:,1])
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    2985         ax.hold(hold)
#    2986     try:
# -> 2987         ret = ax.plot(*args, **kwargs)
#    2988         draw_if_interactive()
#    2989     finally:
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    4135         lines = []
#    4136
# -> 4137         for line in self._get_lines(*args, **kwargs):
#    4138             self.add_line(line)
#    4139             lines.append(line)
#
# ...

# %%
dark = average("dark_1s_*.txt",plot=True)
plt.plot(dark[:,0],dark[:,1])

# %%
plasma = average("plasma_bulb*.txt",plot=True)
plt.figure()
# plt.plot(plasma[:,0],plasma[:,0]);

# %%
plasma[:,0]==dark[:,0]

# %%
dark_subtracted =np.zeros_like(plasma)

# %%
dark_subtracted= plasma-dark

# %%
dark_subtracted[0] = plasma[0] #basically equal to arange(0,2048)

# %%
dark_subtracted[:,1235]

# %% [markdown]
# Not supposed to average these:

# %%
data_lst = glob.glob("plasma_bulb*")
num_sets=len(data_lst)
# x = np.zeros((2048,),'float64')
I = np.zeros((2048,),'float64')
#     print num_sets
mega_Idata = []
for i in data_lst:
    data = np.genfromtxt(i, skip_header=17, skip_footer=1)
    mega_Idata.append(data[:,1])
# print mega_Idata
mega_pixdata = []
for n in np.arange(2048):
    pix1 = []
    for i in mega_Idata:
    #     print i 
    #     print i[0]
        pix1.append(i[n])
    mega_pixdata.append(pix1)
####################################
ddata_lst = glob.glob("dark_1s_*")
dnum_sets=len(data_lst)
# x = np.zeros((2048,),'float64')
I = np.zeros((2048,),'float64')
#     print num_sets
dmega_Idata = []
for i in ddata_lst:
    data = np.genfromtxt(i, skip_header=17, skip_footer=1)
    dmega_Idata.append(data[:,1])
# print mega_Idata
dmega_pixdata = []
for n in np.arange(2048):
    dpix1 = []
    for i in dmega_Idata:
    #     print i 
    #     print i[0]
        dpix1.append(i[n])
    dmega_pixdata.append(pix1)

# %%
mega_Idata_subtracted = np.array(mega_Idata)-np.array(dmega_Idata)

# %%
n=0
for i in mega_Idata_subtracted:
    n+=1
    if (n>10):
        break
    print i

# %%
mulst = []
varlst=[]
for i in mega_Idata_subtracted:
    mu = np.mean(i)
    var = np.std(i)**2
    mulst.append(mu)
    varlst.append(var)
plt.ylabel("Variance[ADU$^2$]")
plt.xlabel("Mean[ADU]")
plt.xlim(10**1,10**2)
plt.loglog(mulst,varlst,'.')

# %%
# for pix in np.arange(2048):
#     pixel.append(mega_Idata_subtracted[:,pix])

# %%
# mega_Idata

# %% [markdown]
# ### Redoing Centroid Analysis on 60w lightbulb Averaged and Dark-subtracted dataset (Post-processed data)

# %%
cd ../Robot/
# Out:
# /Users/dorislee/Desktop/Fall2014/AY120/lab2/Robot

# %%
data = np.genfromtxt("darkness_3ms_0000.txt", skip_header=17, skip_footer=1)
plt.plot(np.arange(2048),data[:,1])
plt.xlim(0,2048)
plt.ylim(100,140)
# Out:
# (100, 140)

# %%
cd ../Robot/
# Out:
# /Users/dorislee/Desktop/Fall2014/AY120/lab2/Robot

# %%
ddata_lst = glob.glob("darkness_10m*")
num_sets = len(ddata_lst)
print num_sets
# print ddata_lst
dnum_sets=len(ddata_lst)
# x = np.zeros((2048,),'float64')
I = np.zeros((2048,),'float64')
#     print num_sets
dmega_Idata = []
for i in ddata_lst:
    data = np.genfromtxt(i, skip_header=17, skip_footer=1)
#     print data[:,1]
    dmega_Idata.append(data[:,1])
# print dmega_Idata
# print mega_Idata
# dmega_pixdata = []
# for n in np.arange(2048):
#     dpix1 = []
#     for i in dmega_Idata:
#     #     print i 
#     #     print i[0]
#         dpix1.append(i[n])
#     dmega_pixdata.append(dpix1)
# Out:
# 1000

# %%
dmega_Idata = np.array(dmega_Idata)

# %%
dmega_Idata.shape
# Out:
# (1000, 2048)

# %%
plt.plot(dmega_Idata[10])

# %%
cd ../ROBOT_lab2/
# Out:
# /Users/dorislee/Desktop/Fall2014/AY120/lab2/ROBOT_lab2

# %%
data = np.genfromtxt("60w_lightbulb_10ms_0000.txt", skip_header=17, skip_footer=1)
plt.plot(np.arange(2048),data[:,1])
plt.xlim(0,2048)
# plt.ylim(100,140)
# Out:
# (0, 2048)

# %%
data_lst = glob.glob("60w_lightbulb_10ms_*")
num_sets=len(data_lst)
print num_sets
# x = np.zeros((2048,),'float64')
I = np.zeros((2048,),'float64')
#     print num_sets
mega_Idata = []
for i in data_lst:
    data = np.genfromtxt(i, skip_header=17, skip_footer=1)
    mega_Idata.append(data[:,1])
# print mega_Idata
mega_pixdata = []
for n in np.arange(2048):
    pix1 = []
    for i in mega_Idata:
    #     print i 
    #     print i[0]
        pix1.append(i[n])
    mega_pixdata.append(pix1)
mega_Idata = np.array(mega_Idata)
# Out:
# 1000

# %%
mega_Idata.shape
# Out:
# (1000, 2048)

# %%
mega_Idata_subtracted = np.array(mega_Idata)-np.array(dmega_Idata)

# %%
print mega_Idata_subtracted
# Out:
# [[   0.   24.   23. ...,  621.  617.  624.]
#  [   0.   24.   21. ...,  638.  636.  623.]
#  [   0.   24.   27. ...,  642.  619.  607.]
#  ...,
#  [   0.   21.   23. ...,  644.  636.  623.]
#  [   0.   24.   24. ...,  633.  619.  604.]
#  [   0.   25.   26. ...,  639.  623.  622.]]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(mega_Idata[0],label= "Raw data")
plt.plot(mega_Idata_subtracted[0],color = "red",label = "Dark subtracted")
title = "Spectrum of 1000 sample of 60W lightbulb"
plt.title(title)
plt.xlim(0,2048)
plt.xlabel("Pixel Number",fontsize=12)
plt.ylabel("Intensity[ADU]",fontsize=12)
# plt.plot(x/num_sets,I/num_sets)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
from matplotlib.legend_handler import HandlerLine2D
plt.legend(loc='upper left',prop={'size':12},numpoints=1)

# %%
mega_Idata_subtracted
# Out:
# array([[   0.,   24.,   23., ...,  621.,  617.,  624.],
#        [   0.,   24.,   21., ...,  638.,  636.,  623.],
#        [   0.,   24.,   27., ...,  642.,  619.,  607.],
#        ...,
#        [   0.,   21.,   23., ...,  644.,  636.,  623.],
#        [   0.,   24.,   24., ...,  633.,  619.,  604.],
#        [   0.,   25.,   26., ...,  639.,  623.,  622.]])

# %%
# mega_Idata_subtracted[:,0]

# %%
mulst = []
varlst=[]
for pix in np.arange(2048):
    pix_all_temp = mega_Idata_subtracted[:,pix]
    mu = np.mean(pix_all_temp)
    var = np.std(pix_all_temp)**2
    mulst.append(mu)
    varlst.append(var)

# %%
plt.plot(mulst,varlst,'.')

# %%
plt.loglog(mulst,varlst,'.')
# plt.xlim(20,100)

# %%
[i for i in mulst if i<0]
# Out:
# []

# %%
[i for i in varlst if i<0]
# Out:
# []

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
plt.loglog(mulst,varlst,'.',label = "Pixel datapoints")
plt.xlim(10**1,5*10**3)
plt.ylabel("Variance[ADU$^2$]",fontsize =12 )
plt.xlabel("Mean[ADU]",fontsize=12)
plt.title ("Variance/mean plot for 1000 dark-subtracted spectra",fontsize=12)

z = np.polyfit(mulst,varlst,1)
#(pix, wavelength, 3) #lets fit to 5th order, but we'll probably find that the  3,4th order coefficient is 0  (becareful not to overfit) 
print z
p = np.poly1d(z)
print p
np.where()
# #x = np.arange(10,10**3,100)
# y=np.array(mulst)*(-0.49129471)-5
# plt.loglog(mulst,abs(y),"red")
plt.loglog(mulst,p(mulst),color="red",label= "Linear fit")
# ax.annotate('local max', xy=(2, 1), xytext=(3, 1.5),fontsize=12)
# ax.annotate("Tester",xy=(0,0),xytext=(0,0))
# ax.annotate("Intercept = ".format(z[-1],xy=(0,10))#, xytext=(0,0),fontsize=12)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
from matplotlib.legend_handler import HandlerLine2D
plt.legend(loc='upper left',prop={'size':12},numpoints=1)
plt.show()
# Out:
# [  0.29129471 -30.75527346]
#
# 0.2913 x - 30.76

# %%
x = np.arange(10,10**3)
y = 0.29129471*x-30.75527346
plt.plot(y)

# %%
y=np.array(mulst)*(-0.29129471)-30.75527346
plt.loglog(mulst,abs(y),"red")

# %%
# mulst = []
# varlst=[]
# for i in mega_Idata_subtracted:
#     mu = np.mean(i)
#     var = np.std(i)**2
#     mulst.append(mu)
#     varlst.append(var)
# plt.ylabel("Variance[ADU$^2$]")
# plt.xlabel("Mean[ADU]")
# plt.xlim(8.3*10**2,8.5*10**2)
# plt.plot(mulst,varlst,'.')
# # plt.loglog(mulst,varlst,'.')
