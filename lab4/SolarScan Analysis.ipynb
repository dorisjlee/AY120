# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import mpld3
import astropy.io.fits as pf
import os
import glob
from matplotlib.colors import LogNorm
os.chdir("SolarScans/")
os.getcwd()
# Out:
# '/Users/dorislee/Desktop/Fall2014/AY120/lab4/SolarScans'

# %%
os.chdir("solar-scan-11-25-9/")

# %%
fits1 = "solar-scan-11-25-9-001.fits"
x = pf.getdata(fits1)
imp = plt.imshow(x,cmap='gray_r',vmin=500,vmax=2500,origin="lower") 
plt.colorbar()
plt.axis("tight")
# Out:
# (-0.5, 1047.5, -0.5, 1023.5)

# %%
mpld3.enable_notebook()

# %%
x[805,163]
# Out:
# 1249.0

# %%
fits1 = "solar-scan-11-25-9-030.fits"
x = pf.getdata(fits1)
imp = plt.imshow(x[::-1][255:275,:],cmap='gray_r',vmin=500,vmax=2500,origin="lower") 
plt.colorbar()
plt.axis("tight")
# Out:
# (-0.5, 1047.5, -0.5, 19.5)

# %% [markdown]
# ### Time Series of total integrated intensity on CCD

# %%
mpld3.disable_notebook()

# %%
intensity_lst = []
for i in glob.glob("solar-scan-11-25-9-*.fits"):
    x = pf.getdata(i)
    intensity_lst.append(sum(x))

# %%
plt.plot(intensity_lst,'o')

# %% [markdown]
# ##### We can see the effect of limb darkening because if there is no limb darkening then we would expect to see an absolute valued step function. But instead we see a smoother transition, then drop off because there is a difference between the background and the solar limb intensity.

# %%
for n  in np.arange(5,10):
    os.chdir("../solar-scan-11-25-{}/".format(n))
    intensity_lst = []
    for i in glob.glob("solar-scan-11-25-{}-*.fits".format(n)):
        x = pf.getdata(i)
        intensity_lst.append(sum(x))
    plt.plot(intensity_lst,'o')

# %% [markdown]
# ### Intensity relation obtained from Eddington approximation (C&O Eq. 9-58)

# %% [markdown]
# $\frac{I(\theta)}{I(\theta=0)}= \frac{2}{5}+\frac{3}{5}cos\theta$

# %% [markdown]
# let b = impact parameter be your varying parameter so you know how far across you are cutting across the sun
#
# $cos\theta = \frac{\sqrt{R^2-b^2}}{R}$

# %%
median(intensity_lst)
# Out:
# 2.4719263e+09

# %%
intensity = median(intensity_lst)*np.array(intensity_lst)

# %%
theta = np.linspace(-pi/2.,pi/2.)
plt.plot(intensity_lst,'o')
# plt.plot(median(intensity_lst[20:70])*(2./5.+3./5.*np.cos(theta)))
import numpy as np
from scipy.optimize import curve_fit
def func(x, a, b, c):
    return a * (2./5.+3./5.*np.cos(theta+b)) + c
# xdata = np.linspace(0, 4, 50)
# y = func(theta, 2.5, 1.3, 0.5)
# ydata = y + 0.2 * np.random.normal(size=len(xdata))
popt, pcov = curve_fit(func, theta, intensity_lst)
# plt.plot(xdata,ydata,'o')
# plt.plot(theta,func(xdata,popt[0],popt[1],popt[2]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-7baf2d51b0f9> in <module>()
#       9 # y = func(theta, 2.5, 1.3, 0.5)
#      10 # ydata = y + 0.2 * np.random.normal(size=len(xdata))
# ---> 11 popt, pcov = curve_fit(func, theta, intensity_lst)
#      12 # plt.plot(xdata,ydata,'o')
#      13 # plt.plot(theta,func(xdata,popt[0],popt[1],popt[2]))
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/scipy/optimize/minpack.pyc in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, **kw)
#     553     # Remove full_output from kw, otherwise we're passing it in twice.
#     554     return_full = kw.pop('full_output', False)
# --> 555     res = leastsq(func, p0, args=args, full_output=1, **kw)
#     556     (popt, pcov, infodict, errmsg, ier) = res
#     557
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/scipy/optimize/minpack.pyc in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     367     if not isinstance(args, tuple):
#     368         args = (args,)
# --> 369     shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     370     m = shape[0]
#     371     if n > m:
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/scipy/optimize/minpack.pyc in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      18 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      19                 output_shape=None):
# ---> 20     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      21     if (output_shape is not None) and (shape(res) != output_shape):
#      22         if (output_shape[0] != 1):
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/scipy/optimize/minpack.pyc in _general_function(params, xdata, ydata, function)
#     443
#     444 def _general_function(params, xdata, ydata, function):
# --> 445     return function(xdata, *params) - ydata
#     446
#     447
#
# ValueError: operands could not be broadcast together with shapes (50,) (85,)

# %%
import numpy as np
from scipy.optimize import curve_fit
def func(x, a, b, c):
    return a * np.exp(-b * x) + c
xdata = np.linspace(0, 4, 50)
y = func(xdata, 2.5, 1.3, 0.5)
ydata = y + 0.2 * np.random.normal(size=len(xdata))
popt, pcov = curve_fit(func, xdata, ydata)
plt.plot(xdata,ydata,'o')
plt.plot(xdata,func(xdata,popt[0],popt[1],popt[2]))

# %%
intensity_lst = np.array(intensity_lst)

# %%
# theta = np.linspace(-pi/2.,pi/2.)
theta = np.linspace(-pi/2.,pi/2.)
plt.plot(intensity_lst-50,'o')
center_shift=0
plt.plot(median(intensity_lst[20:70])*(2./5.+3./5.*np.cos(theta+center_shift)))

# %% [markdown]
# ### From the Wavelength calibration of the 633nm laser's order (processed[::-1][255:275,:])

# %%
p = np.poly1d([  1.38974797e-05,5.82279648e-03,6.26567186e+02])
# Out:
# 626.58477946675725

# %%
p
# Out:
# poly1d([  1.38974797e-05,   5.82279648e-03,   6.26567186e+02])
