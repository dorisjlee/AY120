# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Show and Tell Questions

# %% [markdown]
# 1) What is your group's plan/schedule for completing the lab?
#
# 2) Describe the physical properties of the spectrometer. What is the resolving
# power of the instrument?
#
# 3) Show your calibration data that you collected.
#
# 4) What is the wavelength calibration of the spectrometer?

# %% [markdown]
# ### Calibration Data (Ne, Q, Laser)

# %% [markdown]
# Q for quartz-halogen lamp

# %%
import mpld3
import astropy.io.fits as pf
import os
import glob
from matplotlib.colors import LogNorm
os.chdir("robot-2014-11-24")
os.getcwd()
# Out:
# '/Users/dorislee/Desktop/Fall2014/AY120/lab4/robot-2014-11-24'

# %%
# for i in glob.glob("Ne*"):
#     print i

# %%
mpld3.enable_notebook()
# mpld3.disable_notebook()

# %% [markdown]
# ### Not sure how to read NIST Atomic Spectra database?? upper and lower limit? (Given Neon 633nm)

# %%
x.shape
# Out:
# (1024, 1048)

# %%
fits1 = "Ne-001.fit"
x = pf.getdata(fits1)

# %%
def neon_dots(data,threshold=40000,plot =False):
    #Don't modify original data
    x = np.copy(data)
    x = x[::-1]
    # we actually find that most of this stuff can be cut away by simply eliminating the stuff in overscan column (dark pixels)
    x = x[:,:1024,] #Truncate the overscan columns
    #See if we can use maximum values to automatically determine the threshold?
    # print heapq.nlargest(5,x.flatten())
    #Preprocessing: Masking Bad Columns
#     x[100:,]=0
#     Bad Column masking
    x[:,1023:]=0
    x[1023:,]=0
    x[:,256]=0
    x[255]=0
    x[:,1002]=0
    x[0,:]=0
    # **** Remember that your data is flipped around when you are plotting!! So you also need to do this when you are finding these values, or else these values are flipped. (This took 3 hours to debug!!)
    coord_lst =  np.array(np.where(x>threshold))
    plt.figure()
    if (plot):
        imp = plt.imshow(x,cmap='gray_r',vmin=0,vmax=8000,origin="lower") 
        plt.plot(coord_lst[1],coord_lst[0],'.',ms=2,color='r')
        plt.colorbar()
        plt.axis("tight")

# %%
neon_dots(x,2500,True)

# %%
fits1 = "Q-001.fit"
x = pf.getdata(fits1)
imp = plt.imshow(x,cmap='gray_r',vmin=500,vmax=2500,origin="lower") 
plt.colorbar()
plt.axis("tight")
# Out:
# (-0.5, 1047.5, -0.5, 1023.5)

# %%
fits1 = "laser-001.fit"
plt.figure()
x = pf.getdata(fits1)
plt.xlim(300,500)
plt.ylim(700,800)
imp = plt.imshow(x,cmap='gray_r',vmin=1000,vmax=5000,origin="lower") 
plt.colorbar()
plt.axis("tight")
# Out:
# (-0.5, 1047.5, -0.5, 1023.5)
