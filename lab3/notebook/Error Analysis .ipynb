# %% [markdown]
# # Tracking Asteriod Daphane

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f', 'random', 'diff']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
import matplotlib.pyplot as plt, mpld3
mpld3.enable_notebook()

# %%
cd ../data/2013Data/101613/
# Out:
# /Users/dorislee/Desktop/Fall2014/AY120/lab3/data/2013Data/101613

# %%
datafile = 'd112.fits'
flat1 = 'd106.fits'

# %% [markdown]
# # Data Reduction Bias and Flats

# %%
import astropy.io.fits as pf
import heapq

# %%
def bsub (fits1,plot=False):
    x =pf.getdata(fits1)
    average = x
    n=0
    #Bias Subtraction
    for i in np.arange(100,105):
        dark = 'd{}.fits'.format(i)
        hdulist = pf.open(dark)
        max_val = max(hdulist[0].data.flatten())
        np.delete(hdulist[0].data ,int(max_val))
        average = average + hdulist[0].data
        n = n + 1
    xb = x - average / float(n)
    if (plot):
        plt.title("After Bias Subtraction")
        imp = plt.imshow(xb[600:300:-1],cmap='gray_r',vmin=1000,vmax=2000)#,norm=LogNorm()) 
        plt.colorbar()
        plt.figure()
        plt.title("Before Bias Subtraction")
        imp = plt.imshow(x[600:300:-1],cmap='gray_r',vmin=700,vmax=1500)#,norm=LogNorm()) 
        plt.colorbar()
    return xb

# %%
from matplotlib.colors import LogNorm
xb = bsub(datafile)
flat = pf.getdata(flat1)
flatb = bsub(flat1) # Bias subtract flatb = flatb/np.median(flatb) # normalize
fig = plt.figure()
ax1 = fig.add_subplot(211)
processed =(xb/flatb)* median(flatb)
plt.title("Without normalization", fontsize=12)
imp = plt.imshow((xb/flatb)[600:300:-1],cmap='gray_r',vmin=0,vmax=0.1)#norm=LogNorm()) 
plt.colorbar()
ax2 = fig.add_subplot(212)
plt.title("With normalization", fontsize=12)
imp = plt.imshow(processed[600:300:-1],cmap='gray_r',vmin=1000,vmax=2000)
plt.colorbar()
plt.tight_layout()

# %% [markdown]
# # Centroid-Finding on this Image

# %% [markdown]
# Ok this matches  20:28:28.31 -13:34:34.2 on the Aladin Sky Atlas, so this is correctly displayed north up

# %%
# a = plt.hist(processed.flatten(), 1000)

# %%
# imp = plt.imshow(processed,cmap='gray_r',vmin=1000,vmax=2000,origin="lower")
# plt.colorbar()
# plt.figure()
# imp = plt.imshow(processed.T,cmap='gray_r',vmin=1000,vmax=2000,origin="lower")
# plt.colorbar()
# plt.figure()
imp = plt.imshow(processed[::-1],cmap='gray_r',vmin=0,vmax=8000,origin="lower")
plt.axis("tight")
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x112837758>

# %%
def find_centroid(data,threshold=40000,plot =False):
    #Don't modify original data
    x = np.copy(data)
    x = x[::-1]
    # we actually find that most of this stuff can be cut away by simply eliminating the stuff in overscan column (dark pixels)
    x = x[:,:1024,] #Truncate the overscan columns
    #See if we can use maximum values to automatically determine the threshold?
    # print heapq.nlargest(5,x.flatten())
    #Preprocessing: Masking Bad Columns
#     x[100:,]=0
#     Bad Column masking
    x[:,1023:]=0
    x[1023:,]=0
    x[:,256]=0
    x[255]=0
    x[:,1002]=0
    x[0,:]=0
    #Four Corner Masking
    x[950:,0:60,]=0
    x[0:50,0:50,]=0
    x[0:15,0:18,]=0
    x[1016:,1016:,]=0
    # **** Remember that your data is flipped around when you are plotting!! So you also need to do this when you are finding these values, or else these values are flipped. (This took 3 hours to debug!!)
    coord_lst =  np.array(np.where(x>threshold))
    plt.figure()
    if (plot):
        imp = plt.imshow(x,cmap='gray_r',vmin=0,vmax=8000,origin="lower") 
        plt.plot(coord_lst[1],coord_lst[0],'*',color='r')
        plt.colorbar()
        plt.axis("tight")
    # Finding centroid
    star_data = [] #each star is a group of points, used later for centroid calculation
    star_lst  = np.array([[],[],[]]) #each star is denoted by (x,y,brightness)
    ################################################
    # METHOD : Sum all values above threshold     #
    ################################################
    #Look around a certain radius the coordinate specified by the list
#     r = 3 #3 pixels for now, sum the intensity profile around the star on a 3-by-3 box
    star_data = []
    for i in np.arange(coord_lst.shape[1]):
    #     print a[0][i],a[1][i]
        tmp = []
        xi = coord_lst[0][i]
        yi = coord_lst[1][i]
        for n in np.arange(coord_lst.shape[1]): #looping through other points
            nx = coord_lst[0][n]
            ny = coord_lst[1][n]
    #         print nx, ny
            r_i = np.sqrt((nx-xi)**2+(ny-yi)**2)
            if (r_i<20 and r_i!=0):
    #             print r_i
                tmp.append([nx,ny])#for clustering only, storing x,y locations
        star_data.append(tmp)
    prev_length = 0 #no length zero, enforce first to store
    cleaned_star_data=[]
    for i in star_data:
        if prev_length!=len(i):
            cleaned_star_data.append(i)        
        prev_length  = len(i)
    unique_len = set([len(i) for i in star_data ])
#     assert len(unique_len)==len(cleaned_star_data)
    return cleaned_star_data

# %%
mpld3.enable_notebook()

# %%
star_lst = find_centroid(processed,5000,True) #Don't go below 1000

# %% [markdown]
# $x = \frac{\sum_{i} x_i I_i}{\sum_{i} I_i}$

# %%
def centroid_calc(star_locs):
    #given a list of grouped points, compute the centroid pixel position (round up to center pixel (int))
#     print star_locs
    x_lst = np.array(star_locs)[:,0]
    y_lst = np.array(star_locs)[:,1]
    I=[]
    for i in np.arange(len(x_lst)):
        I.append(processed[x_lst[i],y_lst[i]])
    I = np.array(I)
    x_cm = sum(x_lst*I)/sum(I)
    y_cm = sum(y_lst*I)/sum(I)
    #return x_cm, y_cm and intensity of star (summed over star)
    return [x_cm,y_cm,sum(I)]

# %%
centroid_calc(star_lst[0])
# Out:
# [476.35988732766862, 652.99737733215704, 16396.52]

# %%
x_lst=[]
y_lst=[]
img_data_stars = [[],[]]

# %%
star_lst= [i for i in star_lst if len(i)>0]

# %%
mpld3.enable_notebook()

# %%
star_info=[]
img_data_stars = [[],[],[]]
for i in star_lst:
    centroid = centroid_calc(i)
    star_info.append(centroid)
    imp = plt.imshow(processed[::-1],cmap='gray_r',vmin=0,vmax=8000,origin="lower")
    img_data_stars[0].append(centroid[1])#Ycm [pix]
    img_data_stars[1].append(centroid[0])#Xcm [pix]
#     img_data_stars[2].append(centroid[2])#Total flux
plt.plot(img_data_stars[0],img_data_stars[1],'.',color="red") #Note the switch    
plt.axis("tight")
#Visually verfied with above pattern
x_error_lst = [] 
y_error_lst = []
for i in np.arange(len(star_lst)):
    x_error = np.sqrt(sum(star_info[i][2]*(np.array(star_lst[i])[:,0]-star_info[i][0])**2)/(sum(star_info[i][2])**2))
    y_error = np.sqrt(sum(star_info[i][2]*(np.array(star_lst[i])[:,1]-star_info[i][1])**2)/(sum(star_info[i][2])**2))
    plt.errorbar(star_info[i][1],star_info[i][0], xerr=x_error, yerr=y_error)
    x_error_lst.append(x_error)
    y_error_lst.append(y_error)
plt.xlim(393,393.35)
plt.ylim(537,537.4)
# Out:
# (537, 537.4)

# %% [markdown]
# # Centroid error

# %% [markdown]
# $\sigma_x^2$= centroid error on $<X>$ of 2ndth star which is actually our identifed asteroid

# %%
img_data_stars[0][1],img_data_stars[1][1]
# Out:
# (393.19408299968711, 537.18671671523316)

# %% [markdown]
# #### Centroid Error on asteroid position, we only care about the one on asteroid

# %%
asteroid_centroid_position_error_x = x_error_lst[2]
asteroid_centroid_position_error_y = y_error_lst[2]

# %%
img_data_stars[0][1],img_data_stars[1][1] 
img_data_stars[0][1] + asteroid_centroid_position_error_x,img_data_stars[1][1] 
img_data_stars[0][1],img_data_stars[1][1] 
img_data_stars[0][1] ,img_data_stars[1][1] +asteroid_centroid_position_error_y

# img_data_stars[0][2]
# Out:
# (393.19408299968711, 393.23702571753603)

# %%
fake_stars_error_conversion = np.array([[img_data_stars[0][1],img_data_stars[0][1] + asteroid_centroid_position_error_x,img_data_stars[0][1]],[img_data_stars[1][1],img_data_stars[1][1],img_data_stars[1][1] +asteroid_centroid_position_error_y]])

# %% [markdown]
# # Matching with USNO Catalog

# %% [markdown]
# subtract 00:00:30 from RA and 00:12:00 from Dec from the numbers you get from fits header

# %%
# import os
# os.chdir("data/2013Data/101613/")

# %%
#HA to DEG Converter
ras = '19:34:34.79' 
des = '-10:01:48.7'
radeg = 15*(float(ras[0:2]) + float(ras[3:5])/60. + float(ras[6:])/3600.)
dsgn = np.sign(float(des[0:3]))
dedeg = float(des[0:3]) + dsgn*float(des[4:6])/60. + dsgn*float(des[7:])/3600.
print "plt.plot({},{},'*',color='red')".format(radeg,dedeg)
# Out:
# plt.plot(293.644958333,-10.0301944444,'*',color='red')

# %%
usno_star_tagged=np.array([[293.693583333,293.699333333,293.70825,293.72225,293.713291667,293.7265,293.658,293.655291667,293.650916667,293.66975,293.680833333,293.719625,293.687375,293.705333333,293.644958333],[-10.0580833333,-10.0488611111,-10.0362777778,-10.0489722222,-10.02825,-10.0173888889,-10.0657777778,-10.036,-10.0284722222,-10.08675,-10.0958333333,-10.0647222222,-10.0442222222,-10.0678888889,-10.0301944444]])
# plt.plot(usno_star_tagged[0],usno_star_tagged[1],'o')

# %%
cd ../101613/
# Out:
# /Users/dorislee/Desktop/Fall2014/AY120/lab3/data/2013Data/101613

# %%
import astropy.io.fits as pf 
import matplotlib.pyplot as plt 
import numpy as np
import urllib as url
s1 = pf.open(datafile)
# Read position from the FITS file and convert RA/DEC to degrees # be sure to check that the header data is reliable. If not
# edit the position by hand.
# ras = s1[0].header['ra']
# des = s1[0].header['dec']
#Header is not at exact location (The following value is found via Aladin)
# 19:34:41.94 -10:04:34.6
# ras = '19:34:41.94'
# des = '-10:04:34.6'
# Approx where asteroid should be 
#19:34:44.16 -10:03:45.7
ras = '19:34:44.16'
des = '-10:03:45.7'
#Lower star of top pattern 
# ras = '19:34:49.87'
# des= '-10:02:08.0'
radeg = 15*(float(ras[0:2]) + float(ras[3:5])/60. + float(ras[6:])/3600.)
dsgn = np.sign(float(des[0:3]))
dedeg = float(des[0:3]) + dsgn*float(des[4:6])/60. + dsgn*float(des[7:])/3600.
fovam = 5.0 # size of square search field in arc min (verified with CCD image)
#chdir to where usno.py lies
import os 
os.chdir("../../../")
from usno import usno
#EPOCH FOR POCO POSITION IS CURRENT DATE
epoch = s1[0].header['EQUINOXU']
name,rad,ded,rmag = usno(radeg,dedeg,fovam,epoch) #Epoch data taken in year of 2013
# w = np.where(rmag < 14.4)[0] # select only bright stars r < 15 mag.
w = np.where(rmag < 15)[0] # select only bright stars r < 15 mag.
plt.plot(rad[w],ded[w],'g.') 
plt.locator_params(axis='x',nbins=4) 
plt.locator_params(axis='y',nbins=4) 
plt.tick_params('x',pad=10)
plt.xlabel('RA [Deg]')
plt.ylabel('Dec [Deg]') 
plt.ticklabel_format(useOffset=False)
plt.axis('scaled')
# plt.xlim([266.11,266.03]) # reverse the x-axis direction
os.chdir("data/2013Data/101613/")
plt.plot(293.684,-10.0626944444,'o',color="red")# approx location of asteroid
plt.plot(293.693583333,-10.0580833333,'*',color='red')#A
plt.plot(293.699333333,-10.0488611111,'*',color='red')#B
plt.plot(293.70825,-10.0362777778,'*',color='red') #C
plt.plot(293.72225,-10.0489722222,'*',color='red')#D
plt.plot(293.713291667,-10.02825,'*',color='red')#E
plt.plot(293.7265,-10.0173888889,'*',color='red')#F
plt.plot(293.658,-10.0657777778,'*',color='red')#G
plt.plot(293.655291667,-10.036,'*',color='red')#H
plt.plot(293.650916667,-10.0284722222,'*',color='red')#I
plt.plot(293.66975,-10.08675,'*',color='red')#J
plt.plot(293.680833333,-10.0958333333,'*',color='red')#K
plt.plot(293.719625,-10.0647222222,'*',color='red')#L
plt.plot(293.687375,-10.0442222222,'*',color='red')#M
plt.plot(293.705333333,-10.0678888889,'*',color='red') #N
plt.plot(293.644958333,-10.0301944444,'*',color='red')#O
# Out:
# Calling Vizier http://webviz.u-strasbg.fr/viz-bin/asu-tsv/?-source=USNO-B1&-c.ra=293.684000&-c.dec=-10.062694&-c.bm=5.0000000/5.0000000&-out.max=unlimited

# %% [markdown]
# #### Find in Aladin Sky Atlas

# %%
usno_star_lst
# Out:
# array([[ 293.645175  ,  293.649917  ,  293.6517759 ,  293.652445  ,
#          293.6559    ,  293.658364  ,  293.671273  ,  293.673384  ,
#          293.673792  ,  293.682189  ,  293.682845  ,  293.688153  ,
#          293.69434646,  293.699839  ,  293.705064  ,  293.70569025,
#          293.7088529 ,  293.709681  ,  293.71404022,  293.720828  ,
#          293.722784  ,  293.667675  ],
#        [ -10.029362  ,  -10.065606  ,  -10.027859  ,  -10.028559  ,
#          -10.036278  ,  -10.066648  ,  -10.086728  ,  -10.038806  ,
#          -10.03912   ,  -10.0958    ,  -10.095659  ,  -10.044025  ,
#          -10.05756303,  -10.048806  ,  -10.067945  ,  -10.06787334,
#          -10.03560837,  -10.096198  ,  -10.02884097,  -10.064531  ,
#          -10.04912   ,  -10.102137  ]])

# %%
#subtract 00:00:30 from RA
ras
#subtract 00:12:00 from Dec 
des
# Out:
# '-10:03:45.7'

# %%
usno_star_lst =  array([rad[w],ded[w]]) #returned star list from USNO

# %%
# usno_star_lst= fake_stars_error_conversion

# %%
fig  = plt.figure()
ax1 = fig.add_subplot(121)
plt.plot(usno_star_lst[0],usno_star_lst[1],'g.') 
plt.locator_params(axis='x',nbins=4) 
plt.locator_params(axis='y',nbins=4) 
plt.tick_params('x',pad=10)
plt.xlabel('RA [Deg]')
plt.ylabel('Dec [Deg]') 
plt.ticklabel_format(useOffset=False)
plt.axis('scaled')
ax2 = fig.add_subplot(122)
plt.plot(img_data_stars[0],img_data_stars[1],'o')
plt.xlabel('X [pixel]')
plt.ylabel('Y [pixel]') 
plt.axis('scaled')
plt.tight_layout()

# %% [markdown]
# ## Tangent plane transformation

# %%
a = usno_star_lst[0] #alpha : list of usno ra [deg]
d = usno_star_lst[1]  #delta : list of usno dec [deg]
a_0 = radeg #alpha_0 : center of CCD image (ra)
d_0 = dedeg #delta_0 : center of CCD image (dec)

#convert degrees to radians 
d = d*np.pi/180.
d_0 = d_0*np.pi/180.
a = a*np.pi/180.
a_0 = a_0*np.pi/180.
#tangent plane projection (get image position on CCD  (X,Y) )
X_stdcoord = -(cos(d)*sin(a-a_0))/(cos(d_0)*cos(d)*cos(a-a_0)+sin(d)*sin(d_0))
Y_stdcoord = -(sin(d_0)*cos(d)*cos(a-a_0)-cos(d_0)*sin(d))/(cos(d_0)*cos(d)*cos(a-a_0)+sin(d)*sin(d_0))

# %%
X_stdcoord #looks right, CCD should be small.
# Out:
# array([  6.67269272e-04,   5.85704704e-04,   5.53824878e-04,
#          5.42324100e-04,   4.82932740e-04,   4.40544453e-04,
#          2.18694816e-04,   1.82447455e-04,   1.75435363e-04,
#          3.11185021e-05,   1.98464305e-05,  -7.13726477e-05,
#         -1.77804874e-04,  -2.72201939e-04,  -3.61974992e-04,
#         -3.72736848e-04,  -4.27128264e-04,  -4.41277370e-04,
#         -5.16289682e-04,  -6.32878710e-04,  -6.66523836e-04,
#          2.80507779e-04])

# %%
# # nominal value from worksheet but different from the actualy telescope value 
# f =16840
# p = 0.015
f = 561000 #[pixels per radian]
p = 1

# %% [markdown]
# ### Pixel (X,Y) to celestial coord (x,y) transformation

# %%
#For Nickel (assuming its an "ideal" camera)
# f = 16840 #[mm]
# p= 0.015 #[mm]
x_0 = 512#center of pixel coord (basically 1024/2)
y_0 = 512
x_pixcoord = f*(X_stdcoord/p)+x_0
y_pixcoord=f*(Y_stdcoord/p)+y_0 #looks right, this is now in pixel coordinates!

# %% [markdown]
# ## Why is USNO data flipped around after tangent plane projection?

# %%
from matplotlib.legend_handler import HandlerLine2D
plt.plot(x_pixcoord,y_pixcoord,'o',label= "USNO")
plt.plot(img_data_stars[0],img_data_stars[1],'*',color="red",label="CCD data")
plt.legend(loc='lower right',prop={'size':12},numpoints=1)
plt.xlabel("x [pixel]",fontsize=12)
plt.ylabel("y [pixel]",fontsize=12)

# %%
# plt.plot(x_pixcoord , "*" , label="x")
# plt.plot(y_pixcoord,".", color="red", label= "y")
# plt.xlabel("x or y [pixel]",fontsize=12)
# plt.ylabel("Pixel offset",fontsize=12)
# plt.legend(loc='lower right',prop={'size':12},numpoints=1)

# %% [markdown]
# # Least Squares

# %% [markdown]
# Do not confuse x_pixcoord with x, x_pixcoord and X_stdcoord is USNO coordinate;
# The goal here is to convert CCD imaging coordinate to RA DEC

# %% [markdown]
# ### Why is f/p different from worksheet

# %%
a_x= np.matrix(np.c_[x_pixcoord])

# %%
B = np.matrix(np.c_[(f/p)*X_stdcoord,(f/p)*Y_stdcoord,np.ones_like(Y_stdcoord)])

# %%
c_x = np.linalg.inv(B.T*B)*B.T*a_x

# %%
a_y= np.matrix(np.c_[y_pixcoord])

# %%
c_y = np.linalg.inv(B.T*B)*B.T*a_y

# %%
T = np.matrix([[(f/p)*c_x.item(0),(f/p)*c_x.item(1),c_x.item(2)],[(f/p)*c_y.item(0),(f/p)*c_y.item(1),c_y.item(2)],[0,0,1]])

# %%
T
# Out:
# matrix([[  5.61000000e+05,  -6.22835117e-11,   5.12000000e+02],
#         [ -4.86589935e-11,   5.61000000e+05,   5.12000000e+02],
#         [  0.00000000e+00,   0.00000000e+00,   1.00000000e+00]])

# %%
f/p
# Out:
# 561000

# %%
sqrt(np.linalg.det(T))
# Out:
# 561000.00000000012

# %% [markdown]
# Since X = (x,y,1)

# %%
img_data_stars = fake_stars_error_conversion

# %%
x_pixcoord = np.matrix(np.c_[img_data_stars[0]])
y_pixcoord = np.matrix(np.c_[img_data_stars[1]])

# %%
x = np.matrix((img_data_stars[0],img_data_stars[1],np.ones_like(img_data_stars[0])))

# %%
X = np.linalg.inv(T)*x

# %%
X_std_coord_final = np.array(X[0])
Y_std_coord_final = np.array(X[1])

# %% [markdown]
# Then convert this into celestial coordinates using the tangent plane equation
#
# (X,Y)$\rightarrow$ ($\alpha$,$\delta$)
#
# and keeping the same a_0,d_0

# %%
a_0 = radeg/180.*np.pi
d_0 = dedeg/180.*np.pi
a = np.arctan(-X_std_coord_final/(cos(d_0)-Y_std_coord_final*sin(d_0)))+a_0
d = np.arcsin((sin(d_0)+Y_std_coord_final*cos(d_0))/((1+np.array(X_std_coord_final)**2+np.array(Y_std_coord_final)**2)**0.5))
a = a/np.pi*180.
d = d/np.pi*180.
a = a[0]
d = d[0]

# %% [markdown]
# #### Manually obtaining the shift vector by grabbing the distance between known matching star

# %%
a_shift_val = (a[2]-usno_star_lst[0][13])
d_shift_val = (d[2]-usno_star_lst[1][13])

# %%
mpld3.enable_notebook()

# %%
usno_star_lst
# Out:
# array([[ 293.645175  ,  293.649917  ,  293.6517759 ,  293.652445  ,
#          293.6559    ,  293.658364  ,  293.671273  ,  293.673384  ,
#          293.673792  ,  293.682189  ,  293.682845  ,  293.688153  ,
#          293.69434646,  293.699839  ,  293.705064  ,  293.70569025,
#          293.7088529 ,  293.709681  ,  293.71404022,  293.720828  ,
#          293.722784  ,  293.667675  ],
#        [ -10.029362  ,  -10.065606  ,  -10.027859  ,  -10.028559  ,
#          -10.036278  ,  -10.066648  ,  -10.086728  ,  -10.038806  ,
#          -10.03912   ,  -10.0958    ,  -10.095659  ,  -10.044025  ,
#          -10.05756303,  -10.048806  ,  -10.067945  ,  -10.06787334,
#          -10.03560837,  -10.096198  ,  -10.02884097,  -10.064531  ,
#          -10.04912   ,  -10.102137  ]])

# %%
xerror
# Out:
# 0.042942717848916345

# %%
xerror = abs(a[2]-a[1])
yerror = abs(d[2]-d[1])
centerx =a[0]
centery = d[0]

# %%
mpld3.disable_notebook()

# %%
import matplotlib.gridspec as gridspec

fig  = plt.figure()

gs = gridspec.GridSpec(2, 1,width_ratios=[55,1])

ax1 = plt.subplot(gs[0])

# ax1 = fig.add_subplot(211)
star_info=[]
img_data_stars = [[],[],[]]
for i in star_lst:
    centroid = centroid_calc(i)
    star_info.append(centroid)
    imp = plt.imshow(processed[::-1],cmap='gray_r',vmin=0,vmax=8000,origin="lower")
    img_data_stars[0].append(centroid[1])#Ycm [pix]
    img_data_stars[1].append(centroid[0])#Xcm [pix]
#     img_data_stars[2].append(centroid[2])#Total flux
plt.plot(img_data_stars[0],img_data_stars[1],'.',color="red",label="41Daphne Centroid") #Note the switch    
plt.axis("tight")
#Visually verfied with above pattern
x_error_lst = [] 
y_error_lst = []
for i in np.arange(len(star_lst)):
    x_error = np.sqrt(sum(star_info[i][2]*(np.array(star_lst[i])[:,0]-star_info[i][0])**2)/(sum(star_info[i][2])**2))
    y_error = np.sqrt(sum(star_info[i][2]*(np.array(star_lst[i])[:,1]-star_info[i][1])**2)/(sum(star_info[i][2])**2))
    plt.errorbar(star_info[i][1],star_info[i][0], xerr=x_error, yerr=y_error,elinewidth=1.8)
    x_error_lst.append(x_error)
    y_error_lst.append(y_error)
plt.xlim(393,393.3)
plt.ylim(537,537.4)
plt.locator_params(axis='x',nbins=4) 
plt.locator_params(axis='y',nbins=3) 
 
# gca().xaxis.set_major_formatter(FormatStrFormatter('%f'))
# gca().yaxis.set_major_formatter(FormatStrFormatter('%f'))
from matplotlib.ticker import FormatStrFormatter
plt.gca().xaxis.set_major_formatter(FormatStrFormatter('%g'))
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%g'))
for tick in ax1.xaxis.get_major_ticks():
    tick.label.set_fontsize(12)
for tick in ax1.yaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
plt.title("CCD Image with Centroid Error Bar",fontsize=12)
plt.xlabel("x [pixel]",fontsize =12 )
plt.ylabel("y [pixel]",fontsize =12 )
plt.legend(loc='upper left',prop={'size':12},numpoints=1)
  
ax2 = plt.subplot(gs[1])
# ax2 = fig.add_subplot(212) 
plt.gca().xaxis.set_major_formatter(FormatStrFormatter('%g'))
# plt.plot(usno_star_lst[0],usno_star_lst[1],'.',ms=8,color="green",label ="USNO");
plt.errorbar(centerx,centery, xerr=xerror , yerr=yerror,elinewidth=1.8)#,label = "Uncertainty range")
plt.plot(a,d,".",label = "Boundary points",color = "red")
# plt.plot((a-a_shift_val)[1],(d-d_shift_val)[1],"x",markeredgewidth =2, ms=8,color="blue", label="Asteroid")
# plt.plot(a-a_shift_val,d-d_shift_val,'.',ms=5,color="red",label ="CCD Data");
plt.locator_params(axis='x',nbins=4) 
plt.locator_params(axis='y',nbins=3) 
plt.tick_params('x',pad=10)
plt.xlabel('RA [deg]',fontsize=12)
# ax.xaxis.labelpad = 20
plt.ylabel('DEC [deg]',fontsize=12) 
plt.title("Centroid Uncertainty in Celestial Coordinates",fontsize=12)
# plt.axis('scaled')
plt.legend(loc='upper left',prop={'size':12},numpoints=1)
plt.gca().xaxis.set_major_formatter(FormatStrFormatter('%f'))
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%f'))
for tick in ax2.xaxis.get_major_ticks():
    tick.label.set_fontsize(12)
for tick in ax2.yaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
plt.xlim(293.69631,293.696330)
plt.tight_layout()

# %%
mpld3.disable_notebook()

# %%
fig = plt.figure()
# ax = plt.axes()
ax = fig.add_subplot(211)
plt.title("2D Motion Path of 41 Daphne",fontsize=12)
plt.xlabel("RA [deg]",fontsize=12)
plt.ylabel("DEC [deg]",fontsize=12)
plt.plot((a-a_shift_val)[1],(d-d_shift_val)[1],"o",color="green",label="2013-10-16")
plt.plot(293.95400586071923,-10.120755702927115,"o",color="red",label="2013-10-17")
# plt.plot(294.656, -10.361,"o",color="yellow",label="2013-10-20")
plt.plot(294.68209574919655, -10.350548498365422,"o",color="yellow",label="2013-10-20")
plt.plot(295.16195724312684,-10.384294242239642,"o",color="blue",label="2013-10-21")
ax.arrow((a-a_shift_val)[1],(d-d_shift_val)[1], 293.95400586071923-(a-a_shift_val)[1]-0.045,-10.120755702927115-(d-d_shift_val)[1]+0.005, head_width=0.015, head_length=0.03, fc='k', ec='k')
ax.arrow(293.95400586071923,-10.120755702927115,294.68209574919655-293.95400586071923-.05, -10.350548498365422--10.120755702927115+0.009, head_width=0.015, head_length=0.03, fc='k', ec='k')
ax.arrow(294.68209574919655, -10.350548498365422,295.16195724312684-294.68209574919655-.05,-10.384294242239642--10.350548498365422, head_width=0.015, head_length=0.03, fc='k', ec='k')
plt.legend(loc='upper right',prop={'size':11},numpoints=1)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(12)
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
pyplot.locator_params(nbins=5)

# %% [markdown]
# #### So how do you obtain the asteroid's ra dec? The stars would have to exactly match!

# %% [markdown]
# ### Manually Match together USNO and CCD stars for residual plots

# %%
# a-usno_star_lst

# %% [markdown]
# # Parallax Determination

# %% [markdown]
# Defining variables
#
# s = $\vec{s}$ ;
# ds = $\dot{s}$ ;
# dds = $\ddot{s}$ ;
# R = $\vec{R}$ ;
# p=$\rho$ ;
# Ti = $\tau_i$

# %% [markdown]
# Subscript denote measurement done on each night
#
# s1 10/16/2013
#
# s2 10/17/2013
#
# s3 10/21/2013

# %%
#RA/DEC [degree]-->[radian]
asteroid_a= (a-a_shift_val)[1]/180.*pi
asteroid_d= (d-d_shift_val)[1]/180.*pi
asteroid_101713_a = 293.95400586071923/180.*pi
asteroid_101713_d = -10.120755702927115/180.*pi
asteroid_102113_a = 295.16195724312684/180.*pi
asteroid_102113_d =  -10.384294242239642/180.*pi

# %%
s1 = np.array([cos(asteroid_a)*cos(asteroid_d),sin(asteroid_a)*cos(asteroid_d),sin(asteroid_d)])
s2 = np.array([cos(asteroid_101713_a)*cos(asteroid_101713_d),sin(asteroid_101713_a)*cos(asteroid_101713_d),sin(asteroid_101713_d)])
s3 = np.array([cos(asteroid_102113_a)*cos(asteroid_102113_d),sin(asteroid_102113_a)*cos(asteroid_102113_d),sin(asteroid_102113_d)])

# %% [markdown]
# #### Oct 16

# %%
from astropy.time import Time

# %%
#[AU]
X_jpl =9.203455880472667E-01
Y_jpl=3.515255751328614E-01
Z_jpl=1.523886251717332E-01
R = np.array([X_jpl,Y_jpl,Z_jpl])
k=0.017202098950 #[AU^3/2 d^-1]
# s_jpl= r-R#unit vector from Earth to target body; from astrometric data

# %%
t1 = Time(s1[0].header["DATE"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1104-c8ae29cfbad4> in <module>()
# ----> 1 t1 = Time(s1[0].header["DATE"])
#
# AttributeError: 'numpy.float64' object has no attribute 'header'

# %% [markdown]
# Becareful when you are converting from degrees to radian, and divide by 180 do floating point division 180. so that integer truncation doesn't yield just 1 or 0 and weird values

# %%
mpld3.disable_notebook()

# %% [markdown]
# #### Oct 17

# %%
X_jpl_2 = 9.133156505080589E-01
Y_jpl_2 = 3.659793733063590E-01
Z_jpl_2 = 1.586550888688789E-01
R2 = np.array([X_jpl_2,Y_jpl_2,Z_jpl_2])

# %%
cd ../101713/

# %%
frame = pf.open("d101.fits")
t2= Time(frame[0].header["DATE"])

# %% [markdown]
# #### Oct 21

# %%
X_jpl_3 = 8.825015460052588E-01 
Y_jpl_3 = 4.226596954178235E-01
Z_jpl_3 = 1.832296673113675E-01
R3 = np.array([X_jpl_3,Y_jpl_3,Z_jpl_3])

# %%
cd ../102113/

# %%
frame = pf.open("d200.fits")
t3= Time(frame[0].header["DATE"])

# %%
# Time interval [days]
T1 = (t2-t1).value
T3 = (t3-t2).value

# %%
ds2 = (T3*(s2-s1)/T1*(T1+T3))+(T1*(s3-s2)/T3*(T1+T3))
dds2 = (2*(s3-s2)/T3*(T1+T3))-(2*(s2-s1)/T1*(T1+T3))

# %% [markdown]
# ### Values too large, check if units of AU. Then check degree or radian.

# %%
R2

# %%
print(ds2)
print (dds2)
#Woah this is moving a bit wayy to fast! (Much better now after fix)

# %%
#Trying to solve for p
r_guess=10
p = 3 #[AU] #Initial guess
p_lst = []
r_lst = []
for i in np.arange(11):
#     print i
#     print "r_guess_initial: ",r_guess
#     if (i>=1):
#         r_guess = r_lst[i-1] #last guess
#     p =r_guess*2
    p = abs(k**2*(1/np.linalg.norm(R2)**3-1/np.linalg.norm(r_guess**3))*(np.dot(ds2,np.cross(R2,s2)))/(np.dot(ds2,np.cross(dds2,s2))))
    r_guess = np.sqrt(p**2+np.linalg.norm(R2)**2+2*p*np.dot(R2,s2))
    assert np.linalg.norm(R2)==np.sqrt(R2[0]**2+R2[1]**2+R2[2]**2)
#     r_guess = 2*p
#     print "p: ",p
#     print "r_guess_final : ",r_guess
    p_lst.append(p)
    r_lst.append(r_guess)
# print "r_lst:",r_lst
# print "p_lst:",p_lst

# %%
# for i in np.arange(len(p_lst)-1):
#     print i
#     plt.plot(log(abs(p_lst[i+1]-p_lst[i])),'o')
# #     plt.plot(abs(p_lst[i+1]-p_lst[i]),'o')

# %%
mpld3.disable_notebook()
#converge quickly
fig = plt.figure()
ax = fig.add_subplot(211)
plt.title("Convergence of numerical solution for ",fontsize = 12)#$\rho$")
plt.plot(p_lst)
plt.xlabel("Number of steps",fontsize = 12)
# plt.ylabel("$\rho$")

# %%
p_lst[-1] #last one is the most converging one

# %%
s2

# %%
p_lst[-1]*s2

# %%
np.linalg.norm(p_lst[-1]*s2)

# %% [markdown]
# ### The asteroid was 3.04654 AU away from us on the night of Oct 17

# %% [markdown]
# ### The NASA Solar System Bodies web tool says that it should be 2.57 AU !!

# %% [markdown]
# - Discuss possible systematic error (h-->0) taylor approx
# - and other error in calculation or measurement

# %%
#verify that eq(4) hold for computed data (compared with NASA Ephemeris)
x_jpl=1.840228019827501E+00 
y_jpl=-1.776928921396953E+00
z_jpl=-2.557152279422672E-01
r = np.array([x_jpl,y_jpl,z_jpl])
# r ==p*s1

x_jpl_2 = 1.849795188217178E+00
y_jpl_2 = -1.771366800510654E+00
z_jpl_2 = -2.550551203967506E-01
r2 = np.array([x_jpl_2,y_jpl_2,z_jpl_2])
# s2= r-R#unit vector from Earth to target body; from astrometric data


x_jpl_3 = 1.887742260264861E+00 
y_jpl_3 = -1.748812956347293E+00
z_jpl_3 = -2.523707136650389E-01
r3 = np.array([x_jpl_3,y_jpl_3,z_jpl_3])
# s3= r-R#unit vector from Earth to target body; from astrometric data

# These returned values are in RADIANS!!!!!!
a_jpl = np.arctan2((y_jpl-Y_jpl),(x_jpl-X_jpl))*180./pi
p=np.sqrt((x_jpl-X_jpl)**2+(y_jpl-Y_jpl)**2+(z_jpl-Z_jpl)**2)
d_jpl = np.arcsin((z_jpl-Z_jpl)/p)*180./pi

# %%
p = np.sqrt((x_jpl_2-X_jpl_2)**2+(y_jpl_2-Y_jpl_2)**2+(z_jpl_2-Z_jpl_2)**2)

# %%
p

# %%
s2*p

# %% [markdown]
# # Monte Carlo Error Propagation

# %%
def calc_p(R2,s2,ds2,dds2,N=10):
    #Trying to solve for p
    r_guess=10
    p = 3 #[AU] #Initial guess
    p_lst = []
    r_lst = []
    n=0
    for i in np.arange(N):
        p = abs(k**2*(1/np.linalg.norm(R2)**3-1/np.linalg.norm(r_guess**3))*(np.dot(ds2,np.cross(R2,s2)))/(np.dot(ds2,np.cross(dds2,s2))))
        r_guess = np.sqrt(p**2+np.linalg.norm(R2)**2+2*p*np.dot(R2,s2))
#         assert np.linalg.norm(R2)==np.sqrt(R2[0]**2+R2[1]**2+R2[2]**2)
        p_lst.append(p)
        r_lst.append(r_guess)
#         #Just for fun, find out how many times it takes for solution to converge
#         #define convergence as when consecutive solutions yield difference of <0.0001
        
#         diff = 1000
#         if (i>=1):
# #             print i
# #             print r_lst
#             diff = p_lst[i]-p_lst[i-1]
#             print diff
#         if ((abs(diff)< 0.000001) and (n==0)):
#             n=i
    return p_lst[-1],n #last one is the converging value

# %%
import random
sig =10
random.gauss(0,sig)
# Out:
# -19.974386712833002

# %%
asteroid_centroid_position_error #[in pixels]
# Out:
# 0.042942717848891955

# %%
xerror
# Out:
# 4.454118823105091e-06

# %%
yerror #in degrees
# Out:
# 4.4679854642737382e-06

# %%
import random

# %%
R2=R2[:2]
R2
# Out:
# array([ 0.91331565,  0.36597937])

# %%
result = []
converge_N = []
monte_carlo_mean2=[]
monte_carlo_std2=[]
for n in [100000,125000,150000,175000,200000]:
    result_val =0
    for i in np.arange(100000):
    #     n = 0 #record only once
        noise_vector = [random.gauss(0,xerror),random.gauss(0,yerror),0]
        val  = calc_p(R2+noise_vector,s2,ds2,dds2)
        result.append(val[0])
    #     converge_N.append(val[1])
    monte_carlo_std2.append(std(result))
    monte_carlo_mean2.append(mean(result))

# %% [markdown]
# first run of Monte Carlo, then append more
# [100,500,1000,5000,10000,15000,30000,40000,50000,60000,70000,80000,90000,100000]

# %%
monte_carlo_std=[3.7064653019854712e-05,
 3.7077527288630122e-05,
 3.7035803171566256e-05,
 3.7013346600045247e-05,
 3.7012436694403536e-05,
 3.7005347058925661e-05,
 3.7014949966981667e-05,
 3.7014241422241717e-05,
 3.7008774882958304e-05,
 3.7003458107063268e-05,
 3.700864623760215e-05,
 3.7014553001955827e-05,
 3.7004856420349446e-05,
 3.7006176442016113e-05]

# %% [markdown]
# # YOu need to rerun the above and plot the mean!! not std

# %%
plt.plot([100,500,1000,5000,10000,15000,30000,40000,50000,60000,70000,80000,90000,100000],monte_carlo_mean,'o')

# %%
[100,500,1000,5000,10000,15000,50000,100000]:

# %%
mean(result)
# Out:
# 3.0465432045408427

# %%
std(result) #[in degrees]
# Out:
# 3.6823919413912953e-05

# %%
mpld3.enable_notebook()

# %%
from scipy.optimize import curve_fit
plt.figure()
plt.title("Monte Carlo Error Analysis",fontsize=12)
n, bins, patches = plt.hist(result,50);
# add a 'best fit' line
mu = mean(result)
sigma  = std(result)
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=2)

 
# mu = 108.3
# sig = 2.56
def gaussian(x,A):
    return A*(np.exp(-(x-mu)**2/(2*sig**2))/(sig*np.sqrt(2*np.pi)))
from matplotlib.legend_handler import HandlerLine2D
plt.legend(loc='upper left',prop={'size':14.3})
plt.xlim(50,150)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
plt.xlabel("$\rho$",fontsize=12)
plt.ylabel("Frequency",fontsize=12)
plt.show()

# %%
mpld3.disable_notebook()

# %%
from scipy.stats import norm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
fig  = plt.figure()
ax = fig.add_subplot(111)
data = result
# best fit of data
(mu, sigma) = norm.fit(data)

# the histogram of the data
n, bins, patches = plt.hist(data, 50, normed=1, alpha=0.75)

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r-', linewidth=2,label = "$\mu=3.047$")
plt.plot([],'white',label="$\sigma_p=3.68\quad10^{-5}$")

#plot
# rc('text', usetex=False)
plt.xlabel(' ',fontsize=12)
plt.ylabel('Frequency',fontsize=12)
plt.title("Monte Carlo Error Analysis (N=100000)",fontsize=12)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(12)
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(12) 
plt.gca().xaxis.set_major_formatter(FormatStrFormatter('%g'))
plt.gca().yaxis.set_major_formatter(FormatStrFormatter('%g'))
plt.locator_params(axis='x',nbins=6) 
plt.locator_params(axis='y',nbins=6) 
plt.legend(loc='upper left',prop={'size':12},numpoints=1)
plt.xlim(3.0463,3.04675)
# Out:
# (3.0463, 3.04675)

# %% [markdown]
# # Rough estimate of error on astrometry is 3.8241165216418436e-05 degree = 0.00229446991 arc minute
