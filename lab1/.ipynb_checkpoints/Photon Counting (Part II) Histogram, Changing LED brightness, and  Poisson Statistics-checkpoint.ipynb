# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cd data/
# Out:
# /Users/dorislee/Desktop/Fall2014/AY120/lab1/data

# %%
file  = "msjidlmh_140906_1057_50.csv"
x = np.loadtxt(file,delimiter=',',dtype=np.int32)
t = x[:,1]
dt =t[1:] - t[0:-1]

# %%
def histo(bsize,file = "msjidlmh_140906_1057_50.csv"):
    N = bsize
    #binwidth
    bw = (dt.max()-dt.min())/(N-1.)
    bin1 = dt.min()+ bw*np.arange(N)
    #define the array to hold the occurrence count
    bincount= np.array([])
    for bin in bin1:
        count = np.where((dt>=bin)&(dt<bin+bw))[0].size
        bincount = np.append(bincount,count)
    #bin center
    binc = bin1+0.5*bw
    plt.figure()
    plt.plot(binc,bincount,drawstyle= 'steps-mid')
    plt.title("Histogram", fontsize=12)
    plt.xlabel("Interval[ticks]",fontsize=12)
    plt.ylabel("Frequency",fontsize=12)

# %%
histo(500)

# %%
histo(100000)
plt.xlim(0,4000)
plt.ylim(0,700)
# Out:
# (0, 700)

# %% [markdown]
# Afterpulse is seen immediately after the original pulse and then there is a graduate decline of ticks in the next ~3000 clock ticks

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
histo(500000)
plt.xlim(0,4000)
plt.ylim(0,700)
ax.annotate('afterpulse', xy=(250, 250), xytext=(300, 300),arrowprops=dict(facecolor='black', shrink=0.05),)
ax.annotate('original pulse', xy=(100, 500), xytext=(300, 500),arrowprops=dict(facecolor='black', shrink=0.05),)
plt.title("Example of an afterpulse in on tick cycle",fontsize=12)

# %%
cd ../
# Out:
# /Users/dorislee/Desktop/Fall2014/AY120/lab1

# %% [markdown]
# Showing that this is a Poisson process

# %%
len(dt)
# Out:
# 99833

# %%
dt
# Out:
# array([ 163871,  329200,  867973, ...,  153388,  797940, 2579940], dtype=int32)

# %%
#Gating afterpulses
len(dt[np.where(dt>3000.)[0]])
# Out:
# 87387

# %%
dt_gated
# Out:
# 87387

# %%
import matplotlib.pyplot as plt
import numpy as np
file  = "../data/msjidlmh_140906_1057_50.csv"
x = np.loadtxt(file,delimiter=',',dtype=np.int32)
N = 50
t = x[:,1]
dt =t[1:] - t[0:-1]
bw = (dt.max()-dt.min())/(N-1.)
bin1 = dt.min()+ bw*np.arange(N)
bincount= np.array([])
for bin in bin1:
    count = np.where((dt>=bin)&(dt<bin+bw))[0].size
    bincount = np.append(bincount,count)
fig = plt.figure()
ax = fig.add_subplot(111)
binc = bin1+0.5*bw
plt.plot(binc,bincount,drawstyle= 'steps-mid')
plt.xlabel("Interval[ticks]",fontsize=12)
plt.ylabel("Frequency",fontsize=12)
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
num_events = len(dt)
print num_events
delta_t=1.42*10**7
tau = np.mean(dt)
#     plt.plot(num_events*(1./tau) * np.exp(- delta_t/tau))
entries=np.arange(5e6)
plt.plot(30000*(-np.exp(-(entries+delta_t)/tau)+np.exp(-entries/tau)),label="Theoretical prediction") # Not sure why I can not scale by the number of events, but needed to adjust this amplitude parameter .
plt.legend(loc='upper right')
plt.title("Histogram of original data", fontsize=12)
# Out:
# 99833

# %%
dt=dt[np.where(dt>3000.)[0]]
bin1 = dt.min()+ bw*np.arange(N)
bincount= np.array([])
for bin in bin1:
    count = np.where((dt>=bin)&(dt<bin+bw))[0].size
    bincount = np.append(bincount,count)
fig = plt.figure()
ax = fig.add_subplot(111)
binc = bin1+0.5*bw
plt.plot(binc,bincount,drawstyle= 'steps-mid')
plt.xlabel("Interval[ticks]",fontsize=12)
plt.ylabel("Frequency",fontsize=12)
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
num_events = len(dt)
print num_events
delta_t=1.42*10**7
tau = np.mean(dt)
#     plt.plot(num_events*(1./tau) * np.exp(- delta_t/tau))
entries=np.arange(5e6)
plt.plot(18000*(-np.exp(-(entries+delta_t)/tau)+np.exp(-entries/tau)),label="Theoretical Prediction") # Not sure why I can not scale by the number of events, but needed to adjust this amplitude parameter .
plt.title("Histogram of data after gating afterpulses", fontsize=12)
plt.legend(loc='upper right')
# Out:
# 87387

# %%
from scipy.optimize import curve_fit
curve_fit?

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.misc import factorial


# data = np.random.poisson(2, 1000)
data = dt
xlen=len(dt)
print xlen
entries, bin_edges, patches = plt.hist(data, bins=10)#,  normed=True)
#bincenter
bc = 0.5*(bin_edges[1:] + bin_edges[:-1])
def poisson(x,mu):
    return (mu**x/factorial(x)) * np.exp(-mu)
parameters, cov_matrix = curve_fit(poisson, bc, entries) 
print (parameters)
# plot poisson-deviation with fitted parameter
x_plot = np.linspace(0, 6e6,xlen)
plt.plot(x_plot, poisson(x_plot, *parameters), 'r-', lw=2)
# plt.plot(entries)
# Out:
# 99833
# [ 1.]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.misc import factorial


# get poisson deviated random numbers
data = np.random.poisson(2, 1000)

# the bins should be of integer width, because poisson is an integer distribution
entries, bin_edges, patches = plt.hist(data, bins=11, range=[-0.5, 10.5], normed=True)

# calculate binmiddles
bin_middles = 0.5*(bin_edges[1:] + bin_edges[:-1])

# poisson function, parameter lamb is the fit parameter
def poisson(k, lamb):
    return (lamb**k/factorial(k)) * np.exp(-lamb)

# fit with curve_fit
parameters, cov_matrix = curve_fit(poisson, bin_middles, entries) 
print (parameters)
# plot poisson-deviation with fitted parameter
x_plot = np.linspace(0, 20, 1000)

plt.plot(x_plot, poisson(x_plot, *parameters), 'r-', lw=2)
plt.show()
# Out:
# [ 1.92094542]

# %%
t = np.arange(1,8e6)
poisson = (1./t) * np.exp(- delta_t/float(t))
# plot poisson-deviation with fitted parameter
x_plot = np.linspace(0, 8e6, 1000000)
plt.plot(poisson)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8d4cde31d2ef> in <module>()
#       1 t = np.arange(1,8e6)
# ----> 2 poisson = (1./t) * np.exp(- delta_t/float(t))
#       3 # plot poisson-deviation with fitted parameter
#       4 x_plot = np.linspace(0, 8e6, 1000000)
#       5 plt.plot(poisson)
#
# NameError: name 'delta_t' is not defined

# %% [markdown]
# On logscale

# %%
histo(10)
plt.semilogy()
import matplotlib.mlab as mlab
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))

# %%
cd ../changingLEDbrightness_data/

# %% [markdown]
# ### Changing the LED brightness

# %% [markdown]
# Assuming 360 deg for the knob, there is no notable diffference in the squawker sound from 180 to 360, we start from 0 to 90 (max) degree and increase the knob by 15 deg for each dataset.

# %%
cd changingLEDbrightness_data/
# Out:
# /Users/dorislee/Desktop/Fall2014/AY120/lab1/changingLEDbrightness_data

# %%
def calc_sample_stats(file):
    x = np.loadtxt(file,delimiter=',',dtype=np.int32)
    t = x[:,1]
    dt =t[1:] - t[0:-1]
    t1=np.cumsum(dt)
    return [np.mean(dt),np.std(dt),max(t1)]

# %% [markdown]
# For a exponential distribution $\mu$ and $\sigma$ should be the same, $\therefore$ slope =1

# %%
import glob
from matplotlib.legend_handler import HandlerLine2D
mlst = []
stdlst=[]
for i in glob.glob("robot_*"):
    print i
    stats = calc_sample_stats(i)
    print stats[2]
    mlst.append(stats[0])
    stdlst.append(stats[1])
plt.plot(mlst,stdlst,'o')
plt.plot(mlst,stdlst,label="Experimental Result")
plt.ticklabel_format(style='sci', axis='x', scilimits=(0,0))
plt.title("Results from changing LED brightness",fontsize=12)
plt.xlabel("Interval sample mean [ticks]",fontsize=12)
plt.ylabel("Interval standard deviation [ticks]",fontsize=12)
plt.plot(np.arange(9e6),np.arange(9e6),label="Theoretical prediction")
plt.legend(loc='upper left')
# Out:
# robot_140913_1122_40.csv
# 2146378747
# robot_140913_1123_40.csv
# 2147445458
# robot_140913_1124_40.csv
# 2146887956
# robot_140913_1125_40.csv
# 2147264626
# robot_140913_1126_40.csv
# 2147300283
# robot_140913_1127_40.csv
# 2147384396

# %%
np.sort([8740092.9418663438, 6923158.1139419675, 3551622.8331816802, 760160.51764230104, 585288.68911131332, 562078.13608330803])
# Out:
# array([  562078.13608331,   585288.68911131,   760160.5176423 ,
#         3551622.83318168,  6923158.11394197,  8740092.94186634])

# %%
cd ../changingLEDbrightness_data/
# Out:
# /Users/dorislee/Desktop/Fall2014/AY120/lab1/changingLEDbrightness_data

# %% [markdown]
# ### Binned Events

# %%
file= "robot_140913_1127_40.csv" #one on max
x = np.loadtxt(file,delimiter=',',dtype=np.int32)
t = x[:,1]
dt =t[1:] - t[0:-1]
wa = np.where(dt > 3000)[0]
dt = dt[wa]
# Reconstruct the time series (without the 32-bit jumps) 
t1 = np.cumsum(dt)

# %%
np.arange(7)
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
max(t1)/1500.
# Out:
# 3705604.7286666669

# %%
plt.plot(t1) # t1 is the arrival time in clock ticks  without the 32 bit cycling pattern
plt.xlabel("Event number")
plt.ylabel("Time[ticks]")
plt.figure()
bincount=np.array([])
category = np.array([])
# print (len(t1)/1500.) # So we want to figure out how many events occur every 5 seconds.
for i in t1:
    count = np.where((t1<=i+3705604)&(t1>=i))[0].size
    bincount=np.append(bincount,count)
plt.plot(t1,bincount,drawstyle = "steps-mid")
plt.xlabel("Time[ticks]")
plt.ylabel("Counts per bin")

# %%
parameters[0]
# Out:
# 5.6769862583480162

# %%
plt.figure()
hist,binedges=np.histogram(bincount,14)
plt.ylabel("Frequency",fontsize=12)
plt.xlabel("Counts per bin",fontsize=12)
plt.plot(hist,drawstyle = "steps-mid")
from scipy.misc import factorial
# mu = np.mean(binedges)
x=np.arange(14)
def poisson(x,mu):
    return len(dt)*np.exp(-mu)*mu**x/factorial(x)
parameters, cov_matrix = curve_fit(poisson,x,hist) 
print (parameters)
from matplotlib import rc
plt.rc('text', fontsize=12)
plt.plot(poisson(x,parameters), label="$\mu$=5.677")
plt.legend()
# Out:
# [ 5.67698626]
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/__init__.py:784: UserWarning: text.fontsize is deprecated and replaced with font.size; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt))

# %% [markdown]
# If we want 7 bins then each bin has to be $\Delta t=1223$

# %%
len(t1)/7.
# Out:
# 1223.4285714285713

# %% [markdown]
# ### Notes

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-d4373de374a7> in <module>()
# ----> 1 plt.tight_layout()
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/pyplot.pyc in tight_layout(pad, h_pad, w_pad, rect)
#    1253
#    1254     fig = gcf()
# -> 1255     fig.tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    1256     draw_if_interactive()
#    1257
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/figure.pyc in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    1603                                          renderer,
#    1604                                          pad=pad, h_pad=h_pad, w_pad=w_pad,
# -> 1605                                          rect=rect)
#    1606
#    1607         self.subplots_adjust(**kwargs)
#
# /Users/dorislee/.virtualenvs/py27dev/lib/python2.7/site-packages/matplotlib/tight_layout.pyc in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     323         subplots.append(ax)
#     324
# --> 325     max_nrows = max(nrows_list)
#     326     max_ncols = max(ncols_list)
#     327
#
# ValueError: max() arg is an empty sequence

# %% [markdown]
# - when set squawker rate to 0.01 we can hear afterpulse pattern
# - Don't take data too fast on CoinPro so that the time stamp for the file is not overridden.
# - Unable to plot $p(\Delta t) = 1/ \tau * exp(-\Delta t /\tau)$, isn't Poisson process described by $\lambda^k e^{-\lambda}/k!$
